# %%
import nltk.corpus as corpus
import numpy as np

# %% [markdown]
# # Loading Dataset

# %%
word_tag_list = corpus.brown.tagged_sents(tagset="universal")
word_tag_list_train = []
word_tag_list_test = []
count = 0
for element in word_tag_list:
    count += 1
print(count)
# Out:
# 57340

# %%
for iter, element in enumerate(word_tag_list):
    if((iter / count) * 100 < 80):
        word_tag_list_train.append(element)
    else:
        word_tag_list_test.append(element)

# %%
unigram_count = dict()
for sentence in word_tag_list_train:
    for word_tag_pair in sentence:
        word = word_tag_pair[0]
        tag = word_tag_pair[1]
        if word not in unigram_count:
            unigram_count[word] = 0
        unigram_count[word] += 1

# %% [markdown]
# # Preparing Dataset

# %%
train_tags = set()
X = dict()
Y = dict()
W = dict()
for sentence in word_tag_list_train:
    for wordtag_pair in sentence:
        tag = wordtag_pair[1]
        train_tags.add(tag)

# %%
print("The following are the tags in training set", train_tags)
# Out:
# The following are the tags in training set {'VERB', 'CONJ', 'PRON', 'X', 'DET', 'ADP', '.', 'ADV', 'PRT', 'NUM', 'NOUN', 'ADJ'}

# %% [markdown]
# # Logistic Regression

# %%
def get_features(sentence, index):
    features = {
                    'word'              :unigram_count[sentence[index][0]] if sentence[index][0] in unigram_count else 0,
#                     'prefix'            :ord(current_word[0]),
#                     'suffix'            :ord(current_word[-1]),
                    'prev-word'         : -1 if index == 0 else unigram_count[sentence[index - 1][0]] if sentence[index - 1][0] in unigram_count else 0,
                    '2-prev-word'       : -1 if index <= 1 else unigram_count[sentence[index - 2][0]] if sentence[index - 2][0] in unigram_count else 0,
                    'next-word'         : -1 if index >= len(sentence) - 1     else unigram_count[sentence[index + 1][0]] if sentence[index + 1][0] in unigram_count else 0,
                    '2-next-word'       : -1 if index >= len(sentence) - 2     else unigram_count[sentence[index + 2][0]] if sentence[index + 2][0] in unigram_count else 0,
                    'is_first'          : 1 if index == 0  else 0,
                    'is_last'           : 1 if index == len(sentence) - 1  else 0,
                    'is_capitalized'    : 1 if sentence[index][0][0].upper() == sentence[index][0][0]  else 0,
                    'is_all_capitalized': 1 if sentence[index][0].upper() == sentence[index][0] else 0,
                    'is_capitals_inside': 1 if sentence[index][0][1:].lower() != sentence[index][0][1:] else 0,
                    'is_numeric'        : 1 if sentence[index][0].isdigit() else 0,
    }
    return features

# %%
for tag in train_tags:
    X[tag] = []
    Y[tag] = []
    for sentence in word_tag_list_train:
#         print("Training for sentence")
        for i, wordtag_pair in enumerate(sentence):
            appender = []
            x = get_features(sentence, i)
            for t, it in x.items():
                appender.append(it)
            X[tag].append(appender)
            if wordtag_pair[1] == tag:
                Y[tag].append(1)
            else:
                Y[tag].append(0)
    X[tag] = np.array(X[tag])
    Y[tag] = np.array(Y[tag])

# %%
def sigmoid(val):
    ans = 1.0 / (1 + np.exp(-1 * val))
    return ans

# %%
def regression(tag):
    num_iter = 200
    lr = 4e-5
    X_r = X[tag]
    Y_r = Y[tag]
    w = np.zeros(X_r.shape[1])
    for iteration in range(num_iter):
        print("this is the iteration num ", iteration)
        score = np.dot(X_r, w)
        pred = sigmoid(score)
        err = Y_r - pred
        grad = np.dot(X_r.T, err)
        w += lr * grad
    return w

# %%
def train():
    for tag in train_tags:
        print("Entered here")
        W[tag] = regression(tag)
        print("Trained for ", tag)

# %%
train()
# Out:
# Entered here
# this is the iteration num  0
# this is the iteration num  1
# this is the iteration num  2
# /Users/arghyabhattacharya/.virtualenvs/nlp/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp
# this is the iteration num  3
# this is the iteration num  4
# this is the iteration num  5
# this is the iteration num  6
# this is the iteration num  7
# this is the iteration num  8
# this is the iteration num  9
# this is the iteration num  10
# this is the iteration num  11
# this is the iteration num  12
# this is the iteration num  13
# this is the iteration num  14
# this is the iteration num  15
# this is the iteration num  16
# this is the iteration num  17
# this is the iteration num  18
# this is the iteration num  19
# this is the iteration num  20
# this is the iteration num  21
# this is the iteration num  22
# this is the iteration num  23
# this is the iteration num  24
# this is the iteration num  25
# this is the iteration num  26
# this is the iteration num  27
# this is the iteration num  28
# this is the iteration num  29
# this is the iteration num  30
# this is the iteration num  31
# this is the iteration num  32
# this is the iteration num  33
# this is the iteration num  34
# this is the iteration num  35
# this is the iteration num  36
# this is the iteration num  37
# this is the iteration num  38
# this is the iteration num  39
# this is the iteration num  40
# this is the iteration num  41
# this is the iteration num  42
# this is the iteration num  43
# this is the iteration num  44
# this is the iteration num  45
# this is the iteration num  46
# this is the iteration num  47
# this is the iteration num  48
# this is the iteration num  49
# this is the iteration num  50
# this is the iteration num  51
# this is the iteration num  52
# this is the iteration num  53
# this is the iteration num  54
# this is the iteration num  55
# this is the iteration num  56
# this is the iteration num  57
# this is the iteration num  58
# this is the iteration num  59
# this is the iteration num  60
# this is the iteration num  61
# this is the iteration num  62
# this is the iteration num  63
# this is the iteration num  64
# this is the iteration num  65
# this is the iteration num  66
# this is the iteration num  67
# this is the iteration num  68
# this is the iteration num  69
# this is the iteration num  70
# this is the iteration num  71
# this is the iteration num  72
# this is the iteration num  73
# this is the iteration num  74
# this is the iteration num  75
# this is the iteration num  76
# this is the iteration num  77
# this is the iteration num  78
# this is the iteration num  79
# this is the iteration num  80
# this is the iteration num  81
# this is the iteration num  82
# this is the iteration num  83
# this is the iteration num  84
# this is the iteration num  85
# this is the iteration num  86
# this is the iteration num  87
# this is the iteration num  88
# this is the iteration num  89
# this is the iteration num  90
# this is the iteration num  91
# this is the iteration num  92
# this is the iteration num  93
# this is the iteration num  94
# this is the iteration num  95
# this is the iteration num  96
# this is the iteration num  97
# this is the iteration num  98
# this is the iteration num  99
# this is the iteration num  100
# this is the iteration num  101
# this is the iteration num  102
# this is the iteration num  103
# this is the iteration num  104
# this is the iteration num  105
# this is the iteration num  106
# this is the iteration num  107
# this is the iteration num  108
# this is the iteration num  109
# this is the iteration num  110
# this is the iteration num  111
# this is the iteration num  112
# this is the iteration num  113
# this is the iteration num  114
# this is the iteration num  115
# this is the iteration num  116
# this is the iteration num  117
# this is the iteration num  118
# this is the iteration num  119
# this is the iteration num  120
# this is the iteration num  121
# this is the iteration num  122
# this is the iteration num  123
# this is the iteration num  124
# this is the iteration num  125
# this is the iteration num  126
# this is the iteration num  127
# this is the iteration num  128
# this is the iteration num  129
# this is the iteration num  130
# this is the iteration num  131
# this is the iteration num  132
# this is the iteration num  133
# this is the iteration num  134
# this is the iteration num  135
# this is the iteration num  136
# this is the iteration num  137
# this is the iteration num  138
# this is the iteration num  139
# this is the iteration num  140
# this is the iteration num  141
# this is the iteration num  142
# this is the iteration num  143
# this is the iteration num  144
# this is the iteration num  145
# this is the iteration num  146
# this is the iteration num  147
# this is the iteration num  148
# this is the iteration num  149
# this is the iteration num  150
# this is the iteration num  151
# this is the iteration num  152
# this is the iteration num  153
# this is the iteration num  154
# this is the iteration num  155
# this is the iteration num  156
# this is the iteration num  157
# this is the iteration num  158
# this is the iteration num  159
# this is the iteration num  160
# this is the iteration num  161
# this is the iteration num  162
# this is the iteration num  163
# this is the iteration num  164
# this is the iteration num  165
# this is the iteration num  166
# this is the iteration num  167
# this is the iteration num  168
# this is the iteration num  169
# this is the iteration num  170
# this is the iteration num  171
# this is the iteration num  172
# this is the iteration num  173
# this is the iteration num  174
# this is the iteration num  175
# this is the iteration num  176
# this is the iteration num  177
# this is the iteration num  178
# this is the iteration num  179
# this is the iteration num  180
# this is the iteration num  181
# this is the iteration num  182
# this is the iteration num  183
# this is the iteration num  184
# this is the iteration num  185
# this is the iteration num  186
# this is the iteration num  187
# this is the iteration num  188
# this is the iteration num  189
# this is the iteration num  190
# this is the iteration num  191
# this is the iteration num  192
# this is the iteration num  193
# this is the iteration num  194
# this is the iteration num  195
# this is the iteration num  196
# this is the iteration num  197
# this is the iteration num  198
# this is the iteration num  199
# Trained for  VERB
# Entered here
# this is the iteration num  0
# this is the iteration num  1
# this is the iteration num  2
# this is the iteration num  3
# this is the iteration num  4
# this is the iteration num  5
# this is the iteration num  6
# this is the iteration num  7
# this is the iteration num  8
# this is the iteration num  9
# this is the iteration num  10
# this is the iteration num  11
# this is the iteration num  12
# this is the iteration num  13
# this is the iteration num  14
# this is the iteration num  15
# this is the iteration num  16
# this is the iteration num  17
# this is the iteration num  18
# this is the iteration num  19
# this is the iteration num  20
# this is the iteration num  21
# this is the iteration num  22
# this is the iteration num  23
# this is the iteration num  24
# this is the iteration num  25
# this is the iteration num  26
# this is the iteration num  27
# this is the iteration num  28
# this is the iteration num  29
# this is the iteration num  30
# this is the iteration num  31
# this is the iteration num  32
# this is the iteration num  33
# this is the iteration num  34
# this is the iteration num  35
# this is the iteration num  36
# this is the iteration num  37
# this is the iteration num  38
# this is the iteration num  39
# this is the iteration num  40
# this is the iteration num  41
# this is the iteration num  42
# this is the iteration num  43
# this is the iteration num  44
# this is the iteration num  45
# this is the iteration num  46
# this is the iteration num  47
# this is the iteration num  48
# this is the iteration num  49
# this is the iteration num  50
# this is the iteration num  51
# this is the iteration num  52
# this is the iteration num  53
# this is the iteration num  54
# this is the iteration num  55
# this is the iteration num  56
# this is the iteration num  57
# this is the iteration num  58
# this is the iteration num  59
# this is the iteration num  60
# this is the iteration num  61
# this is the iteration num  62
# this is the iteration num  63
# this is the iteration num  64
# this is the iteration num  65
# this is the iteration num  66
# this is the iteration num  67
# this is the iteration num  68
# this is the iteration num  69
# this is the iteration num  70
# this is the iteration num  71
# this is the iteration num  72
# this is the iteration num  73
# this is the iteration num  74
# this is the iteration num  75
# this is the iteration num  76
# this is the iteration num  77
# this is the iteration num  78
# this is the iteration num  79
# this is the iteration num  80
# this is the iteration num  81
# this is the iteration num  82
# this is the iteration num  83
# this is the iteration num  84
# this is the iteration num  85
# this is the iteration num  86
# this is the iteration num  87
# this is the iteration num  88
# this is the iteration num  89
# this is the iteration num  90
# this is the iteration num  91
# this is the iteration num  92
# this is the iteration num  93
# this is the iteration num  94
# this is the iteration num  95
# this is the iteration num  96
# this is the iteration num  97
# this is the iteration num  98
# this is the iteration num  99
# this is the iteration num  100
# this is the iteration num  101
# this is the iteration num  102
# this is the iteration num  103
# this is the iteration num  104
# this is the iteration num  105
# this is the iteration num  106
# this is the iteration num  107
# this is the iteration num  108
# this is the iteration num  109
# this is the iteration num  110
# this is the iteration num  111
# this is the iteration num  112
# this is the iteration num  113
# this is the iteration num  114
# this is the iteration num  115
# this is the iteration num  116
# this is the iteration num  117
# this is the iteration num  118
# this is the iteration num  119
# this is the iteration num  120
# this is the iteration num  121
# this is the iteration num  122
# this is the iteration num  123
# this is the iteration num  124
# this is the iteration num  125
# this is the iteration num  126
# this is the iteration num  127
# this is the iteration num  128
# this is the iteration num  129
# this is the iteration num  130
# this is the iteration num  131
# this is the iteration num  132
# this is the iteration num  133
# this is the iteration num  134
# this is the iteration num  135
# this is the iteration num  136
# this is the iteration num  137
# this is the iteration num  138
# this is the iteration num  139
# this is the iteration num  140
# this is the iteration num  141
# this is the iteration num  142
# this is the iteration num  143
# this is the iteration num  144
# this is the iteration num  145
# this is the iteration num  146
# this is the iteration num  147
# this is the iteration num  148
# this is the iteration num  149
# this is the iteration num  150
# this is the iteration num  151
# this is the iteration num  152
# this is the iteration num  153
# this is the iteration num  154
# this is the iteration num  155
# this is the iteration num  156
# this is the iteration num  157
# this is the iteration num  158
# this is the iteration num  159
# this is the iteration num  160
# this is the iteration num  161
# this is the iteration num  162
# this is the iteration num  163
# this is the iteration num  164
# this is the iteration num  165
# this is the iteration num  166
# this is the iteration num  167
# this is the iteration num  168
# this is the iteration num  169
# this is the iteration num  170
# this is the iteration num  171
# this is the iteration num  172
# this is the iteration num  173
# this is the iteration num  174
# this is the iteration num  175
# this is the iteration num  176
# this is the iteration num  177
# this is the iteration num  178
# this is the iteration num  179
# this is the iteration num  180
# this is the iteration num  181
# this is the iteration num  182
# this is the iteration num  183
# this is the iteration num  184
# this is the iteration num  185
# this is the iteration num  186
# this is the iteration num  187
# this is the iteration num  188
# this is the iteration num  189
# this is the iteration num  190
# this is the iteration num  191
# this is the iteration num  192
# this is the iteration num  193
# this is the iteration num  194
# this is the iteration num  195
# this is the iteration num  196
# this is the iteration num  197
# this is the iteration num  198
# this is the iteration num  199
# Trained for  CONJ
# Entered here
# this is the iteration num  0
# this is the iteration num  1
# this is the iteration num  2
# this is the iteration num  3
# this is the iteration num  4
# this is the iteration num  5
# this is the iteration num  6
# this is the iteration num  7
# this is the iteration num  8
# this is the iteration num  9
# this is the iteration num  10
# this is the iteration num  11
# this is the iteration num  12
# this is the iteration num  13
# this is the iteration num  14
# this is the iteration num  15
# this is the iteration num  16
# this is the iteration num  17
# this is the iteration num  18
# this is the iteration num  19
# this is the iteration num  20
# this is the iteration num  21
# this is the iteration num  22
# this is the iteration num  23
# this is the iteration num  24
# this is the iteration num  25
# this is the iteration num  26
# this is the iteration num  27
# this is the iteration num  28
# this is the iteration num  29
# this is the iteration num  30
# this is the iteration num  31
# this is the iteration num  32
# this is the iteration num  33
# this is the iteration num  34
# this is the iteration num  35
# this is the iteration num  36
# this is the iteration num  37
# this is the iteration num  38
# this is the iteration num  39
# this is the iteration num  40
# this is the iteration num  41
# this is the iteration num  42
# this is the iteration num  43
# this is the iteration num  44
# this is the iteration num  45
# this is the iteration num  46
# this is the iteration num  47
# this is the iteration num  48
# this is the iteration num  49
# this is the iteration num  50
# this is the iteration num  51
# this is the iteration num  52
# this is the iteration num  53
# this is the iteration num  54
# this is the iteration num  55
# this is the iteration num  56
# this is the iteration num  57
# this is the iteration num  58
# this is the iteration num  59
# this is the iteration num  60
# this is the iteration num  61
# this is the iteration num  62
# this is the iteration num  63
# this is the iteration num  64
# this is the iteration num  65
# this is the iteration num  66
# this is the iteration num  67
# this is the iteration num  68
# this is the iteration num  69
# this is the iteration num  70
# this is the iteration num  71
# this is the iteration num  72
# this is the iteration num  73
# this is the iteration num  74
# this is the iteration num  75
# this is the iteration num  76
# this is the iteration num  77
# this is the iteration num  78
# this is the iteration num  79
# this is the iteration num  80
# this is the iteration num  81
# this is the iteration num  82
# this is the iteration num  83
# this is the iteration num  84
# this is the iteration num  85
# this is the iteration num  86
# this is the iteration num  87
# this is the iteration num  88
# this is the iteration num  89
# this is the iteration num  90
# this is the iteration num  91
# this is the iteration num  92
# this is the iteration num  93
# this is the iteration num  94
# this is the iteration num  95
# this is the iteration num  96
# this is the iteration num  97
# this is the iteration num  98
# this is the iteration num  99
# this is the iteration num  100
# this is the iteration num  101
# this is the iteration num  102
# this is the iteration num  103
# this is the iteration num  104
# this is the iteration num  105
# this is the iteration num  106
# this is the iteration num  107
# this is the iteration num  108
# this is the iteration num  109
# this is the iteration num  110
# this is the iteration num  111
# this is the iteration num  112
# this is the iteration num  113
# this is the iteration num  114
# this is the iteration num  115
# this is the iteration num  116
# this is the iteration num  117
# this is the iteration num  118
# this is the iteration num  119
# this is the iteration num  120
# this is the iteration num  121
# this is the iteration num  122
# this is the iteration num  123
# this is the iteration num  124
# this is the iteration num  125
# this is the iteration num  126
# this is the iteration num  127
# this is the iteration num  128
# this is the iteration num  129
# this is the iteration num  130
# this is the iteration num  131
# this is the iteration num  132
# this is the iteration num  133
# this is the iteration num  134
# this is the iteration num  135
# this is the iteration num  136
# this is the iteration num  137
# this is the iteration num  138
# this is the iteration num  139
# this is the iteration num  140
# this is the iteration num  141
# this is the iteration num  142
# this is the iteration num  143
# this is the iteration num  144
# this is the iteration num  145
# this is the iteration num  146
# this is the iteration num  147
# this is the iteration num  148
# this is the iteration num  149
# this is the iteration num  150
# this is the iteration num  151
# this is the iteration num  152
# this is the iteration num  153
# this is the iteration num  154
# this is the iteration num  155
# this is the iteration num  156
# this is the iteration num  157
# this is the iteration num  158
# this is the iteration num  159
# this is the iteration num  160
# this is the iteration num  161
# this is the iteration num  162
# this is the iteration num  163
# this is the iteration num  164
# this is the iteration num  165
# this is the iteration num  166
# this is the iteration num  167
# this is the iteration num  168
# this is the iteration num  169
# this is the iteration num  170
# this is the iteration num  171
# this is the iteration num  172
# this is the iteration num  173
# this is the iteration num  174
# this is the iteration num  175
# this is the iteration num  176
# this is the iteration num  177
# this is the iteration num  178
# this is the iteration num  179
# this is the iteration num  180
# this is the iteration num  181
# this is the iteration num  182
# this is the iteration num  183
# this is the iteration num  184
# this is the iteration num  185
# this is the iteration num  186
# this is the iteration num  187
# this is the iteration num  188
# this is the iteration num  189
# this is the iteration num  190
# this is the iteration num  191
# this is the iteration num  192
# this is the iteration num  193
# this is the iteration num  194
# this is the iteration num  195
# this is the iteration num  196
# this is the iteration num  197
# this is the iteration num  198
# this is the iteration num  199
# Trained for  PRON
# Entered here
# this is the iteration num  0
# this is the iteration num  1
# this is the iteration num  2
# this is the iteration num  3
# this is the iteration num  4
# this is the iteration num  5
# this is the iteration num  6
# this is the iteration num  7
# this is the iteration num  8
# this is the iteration num  9
# this is the iteration num  10
# this is the iteration num  11
# this is the iteration num  12
# this is the iteration num  13
# this is the iteration num  14
# this is the iteration num  15
# this is the iteration num  16
# this is the iteration num  17
# this is the iteration num  18
# this is the iteration num  19
# this is the iteration num  20
# this is the iteration num  21
# this is the iteration num  22
# this is the iteration num  23
# this is the iteration num  24
# this is the iteration num  25
# this is the iteration num  26
# this is the iteration num  27
# this is the iteration num  28
# this is the iteration num  29
# this is the iteration num  30
# this is the iteration num  31
# this is the iteration num  32
# this is the iteration num  33
# this is the iteration num  34
# this is the iteration num  35
# this is the iteration num  36
# this is the iteration num  37
# this is the iteration num  38
# this is the iteration num  39
# this is the iteration num  40
# this is the iteration num  41
# this is the iteration num  42
# this is the iteration num  43
# this is the iteration num  44
# this is the iteration num  45
# this is the iteration num  46
# this is the iteration num  47
# this is the iteration num  48
# this is the iteration num  49
# this is the iteration num  50
# this is the iteration num  51
# this is the iteration num  52
# this is the iteration num  53
# this is the iteration num  54
# this is the iteration num  55
# this is the iteration num  56
# this is the iteration num  57
# this is the iteration num  58
# this is the iteration num  59
# this is the iteration num  60
# this is the iteration num  61
# this is the iteration num  62
# this is the iteration num  63
# this is the iteration num  64
# this is the iteration num  65
# this is the iteration num  66
# this is the iteration num  67
# this is the iteration num  68
# this is the iteration num  69
# this is the iteration num  70
# this is the iteration num  71
# this is the iteration num  72
# this is the iteration num  73
# this is the iteration num  74
# this is the iteration num  75
# this is the iteration num  76
# this is the iteration num  77
# this is the iteration num  78
# this is the iteration num  79
# this is the iteration num  80
# this is the iteration num  81
# this is the iteration num  82
# this is the iteration num  83
# this is the iteration num  84
# this is the iteration num  85
# this is the iteration num  86
# this is the iteration num  87
# this is the iteration num  88
# this is the iteration num  89
# this is the iteration num  90
# this is the iteration num  91
# this is the iteration num  92
# this is the iteration num  93
# this is the iteration num  94
# this is the iteration num  95
# this is the iteration num  96
# this is the iteration num  97
# this is the iteration num  98
# this is the iteration num  99
# this is the iteration num  100
# this is the iteration num  101
# this is the iteration num  102
# this is the iteration num  103
# this is the iteration num  104
# this is the iteration num  105
# this is the iteration num  106
# this is the iteration num  107
# this is the iteration num  108
# this is the iteration num  109
# this is the iteration num  110
# this is the iteration num  111
# this is the iteration num  112
# this is the iteration num  113
# this is the iteration num  114
# this is the iteration num  115
# this is the iteration num  116
# this is the iteration num  117
# this is the iteration num  118
# this is the iteration num  119
# this is the iteration num  120
# this is the iteration num  121
# this is the iteration num  122
# this is the iteration num  123
# this is the iteration num  124
# this is the iteration num  125
# this is the iteration num  126
# this is the iteration num  127
# this is the iteration num  128
# this is the iteration num  129
# this is the iteration num  130
# this is the iteration num  131
# this is the iteration num  132
# this is the iteration num  133
# this is the iteration num  134
# this is the iteration num  135
# this is the iteration num  136
# this is the iteration num  137
# this is the iteration num  138
# this is the iteration num  139
# this is the iteration num  140
# this is the iteration num  141
# this is the iteration num  142
# this is the iteration num  143
# this is the iteration num  144
# this is the iteration num  145
# this is the iteration num  146
# this is the iteration num  147
# this is the iteration num  148
# this is the iteration num  149
# this is the iteration num  150
# this is the iteration num  151
# this is the iteration num  152
# this is the iteration num  153
# this is the iteration num  154
# this is the iteration num  155
# this is the iteration num  156
# this is the iteration num  157
# this is the iteration num  158
# this is the iteration num  159
# this is the iteration num  160
# this is the iteration num  161
# this is the iteration num  162
# this is the iteration num  163
# this is the iteration num  164
# this is the iteration num  165
# this is the iteration num  166
# this is the iteration num  167
# this is the iteration num  168
# this is the iteration num  169
# this is the iteration num  170
# this is the iteration num  171
# this is the iteration num  172
# this is the iteration num  173
# this is the iteration num  174
# this is the iteration num  175
# this is the iteration num  176
# this is the iteration num  177
# this is the iteration num  178
# this is the iteration num  179
# this is the iteration num  180
# this is the iteration num  181
# this is the iteration num  182
# this is the iteration num  183
# this is the iteration num  184
# this is the iteration num  185
# this is the iteration num  186
# this is the iteration num  187
# this is the iteration num  188
# this is the iteration num  189
# this is the iteration num  190
# this is the iteration num  191
# this is the iteration num  192
# this is the iteration num  193
# this is the iteration num  194
# this is the iteration num  195
# this is the iteration num  196
# this is the iteration num  197
# this is the iteration num  198
# this is the iteration num  199
# Trained for  X
# Entered here
# this is the iteration num  0
# this is the iteration num  1
# this is the iteration num  2
# this is the iteration num  3
# this is the iteration num  4
# this is the iteration num  5
# this is the iteration num  6
# this is the iteration num  7
# this is the iteration num  8
# this is the iteration num  9
# this is the iteration num  10
# this is the iteration num  11
# this is the iteration num  12
# this is the iteration num  13
# this is the iteration num  14
# this is the iteration num  15
# this is the iteration num  16
# this is the iteration num  17
# this is the iteration num  18
# this is the iteration num  19
# this is the iteration num  20
# this is the iteration num  21
# this is the iteration num  22
# this is the iteration num  23
# this is the iteration num  24
# this is the iteration num  25
# this is the iteration num  26
# this is the iteration num  27
# this is the iteration num  28
# this is the iteration num  29
# this is the iteration num  30
# this is the iteration num  31
# this is the iteration num  32
# this is the iteration num  33
# this is the iteration num  34
# this is the iteration num  35
# this is the iteration num  36
# this is the iteration num  37
# this is the iteration num  38
# this is the iteration num  39
# this is the iteration num  40
# this is the iteration num  41
# this is the iteration num  42
# this is the iteration num  43
# this is the iteration num  44
# this is the iteration num  45
# this is the iteration num  46
# this is the iteration num  47
# this is the iteration num  48
# this is the iteration num  49
# this is the iteration num  50
# this is the iteration num  51
# this is the iteration num  52
# this is the iteration num  53
# this is the iteration num  54
# this is the iteration num  55
# this is the iteration num  56
# this is the iteration num  57
# this is the iteration num  58
# this is the iteration num  59
# this is the iteration num  60
# this is the iteration num  61
# this is the iteration num  62
# this is the iteration num  63
# this is the iteration num  64
# this is the iteration num  65
# this is the iteration num  66
# this is the iteration num  67
# this is the iteration num  68
# this is the iteration num  69
# this is the iteration num  70
# this is the iteration num  71
# this is the iteration num  72
# this is the iteration num  73
# this is the iteration num  74
# this is the iteration num  75
# this is the iteration num  76
# this is the iteration num  77
# this is the iteration num  78
# this is the iteration num  79
# this is the iteration num  80
# this is the iteration num  81
# this is the iteration num  82
# this is the iteration num  83
# this is the iteration num  84
# this is the iteration num  85
# this is the iteration num  86
# this is the iteration num  87
# this is the iteration num  88
# this is the iteration num  89
# this is the iteration num  90
# this is the iteration num  91
# this is the iteration num  92
# this is the iteration num  93
# this is the iteration num  94
# this is the iteration num  95
# this is the iteration num  96
# this is the iteration num  97
# this is the iteration num  98
# this is the iteration num  99
# this is the iteration num  100
# this is the iteration num  101
# this is the iteration num  102
# this is the iteration num  103
# this is the iteration num  104
# this is the iteration num  105
# this is the iteration num  106
# this is the iteration num  107
# this is the iteration num  108
# this is the iteration num  109
# this is the iteration num  110
# this is the iteration num  111
# this is the iteration num  112
# this is the iteration num  113
# this is the iteration num  114
# this is the iteration num  115
# this is the iteration num  116
# this is the iteration num  117
# this is the iteration num  118
# this is the iteration num  119
# this is the iteration num  120
# this is the iteration num  121
# this is the iteration num  122
# this is the iteration num  123
# this is the iteration num  124
# this is the iteration num  125
# this is the iteration num  126
# this is the iteration num  127
# this is the iteration num  128
# this is the iteration num  129
# this is the iteration num  130
# this is the iteration num  131
# this is the iteration num  132
# this is the iteration num  133
# this is the iteration num  134
# this is the iteration num  135
# this is the iteration num  136
# this is the iteration num  137
# this is the iteration num  138
# this is the iteration num  139
# this is the iteration num  140
# this is the iteration num  141
# this is the iteration num  142
# this is the iteration num  143
# this is the iteration num  144
# this is the iteration num  145
# this is the iteration num  146
# this is the iteration num  147
# this is the iteration num  148
# this is the iteration num  149
# this is the iteration num  150
# this is the iteration num  151
# this is the iteration num  152
# this is the iteration num  153
# this is the iteration num  154
# this is the iteration num  155
# this is the iteration num  156
# this is the iteration num  157
# this is the iteration num  158
# this is the iteration num  159
# this is the iteration num  160
# this is the iteration num  161
# this is the iteration num  162
# this is the iteration num  163
# this is the iteration num  164
# this is the iteration num  165
# this is the iteration num  166
# this is the iteration num  167
# this is the iteration num  168
# this is the iteration num  169
# this is the iteration num  170
# this is the iteration num  171
# this is the iteration num  172
# this is the iteration num  173
# this is the iteration num  174
# this is the iteration num  175
# this is the iteration num  176
# this is the iteration num  177
# this is the iteration num  178
# this is the iteration num  179
# this is the iteration num  180
# this is the iteration num  181
# this is the iteration num  182
# this is the iteration num  183
# this is the iteration num  184
# this is the iteration num  185
# this is the iteration num  186
# this is the iteration num  187
# this is the iteration num  188
# this is the iteration num  189
# this is the iteration num  190
# this is the iteration num  191
# this is the iteration num  192
# this is the iteration num  193
# this is the iteration num  194
# this is the iteration num  195
# this is the iteration num  196
# this is the iteration num  197
# this is the iteration num  198
# this is the iteration num  199
# Trained for  DET
# Entered here
# this is the iteration num  0
# this is the iteration num  1
# this is the iteration num  2
# this is the iteration num  3
# this is the iteration num  4
# this is the iteration num  5
# this is the iteration num  6
# this is the iteration num  7
# this is the iteration num  8
# this is the iteration num  9
# this is the iteration num  10
# this is the iteration num  11
# this is the iteration num  12
# this is the iteration num  13
# this is the iteration num  14
# this is the iteration num  15
# this is the iteration num  16
# this is the iteration num  17
# this is the iteration num  18
# this is the iteration num  19
# this is the iteration num  20
# this is the iteration num  21
# this is the iteration num  22
# this is the iteration num  23
# this is the iteration num  24
# this is the iteration num  25
# this is the iteration num  26
# this is the iteration num  27
# this is the iteration num  28
# this is the iteration num  29
# this is the iteration num  30
# this is the iteration num  31
# this is the iteration num  32
# this is the iteration num  33
# this is the iteration num  34
# this is the iteration num  35
# this is the iteration num  36
# this is the iteration num  37
# this is the iteration num  38
# this is the iteration num  39
# this is the iteration num  40
# this is the iteration num  41
# this is the iteration num  42
# this is the iteration num  43
# this is the iteration num  44
# this is the iteration num  45
# this is the iteration num  46
# this is the iteration num  47
# this is the iteration num  48
# this is the iteration num  49
# this is the iteration num  50
# this is the iteration num  51
# this is the iteration num  52
# this is the iteration num  53
# this is the iteration num  54
# this is the iteration num  55
# this is the iteration num  56
# this is the iteration num  57
# this is the iteration num  58
# this is the iteration num  59
# this is the iteration num  60
# this is the iteration num  61
# this is the iteration num  62
# this is the iteration num  63
# this is the iteration num  64
# this is the iteration num  65
# this is the iteration num  66
# this is the iteration num  67
# this is the iteration num  68
# this is the iteration num  69
# this is the iteration num  70
# this is the iteration num  71
# this is the iteration num  72
# this is the iteration num  73
# this is the iteration num  74
# this is the iteration num  75
# this is the iteration num  76
# this is the iteration num  77
# this is the iteration num  78
# this is the iteration num  79
# this is the iteration num  80
# this is the iteration num  81
# this is the iteration num  82
# this is the iteration num  83
# this is the iteration num  84
# this is the iteration num  85
# this is the iteration num  86
# this is the iteration num  87
# this is the iteration num  88
# this is the iteration num  89
# this is the iteration num  90
# this is the iteration num  91
# this is the iteration num  92
# this is the iteration num  93
# this is the iteration num  94
# this is the iteration num  95
# this is the iteration num  96
# this is the iteration num  97
# this is the iteration num  98
# this is the iteration num  99
# this is the iteration num  100
# this is the iteration num  101
# this is the iteration num  102
# this is the iteration num  103
# this is the iteration num  104
# this is the iteration num  105
# this is the iteration num  106
# this is the iteration num  107
# this is the iteration num  108
# this is the iteration num  109
# this is the iteration num  110
# this is the iteration num  111
# this is the iteration num  112
# this is the iteration num  113
# this is the iteration num  114
# this is the iteration num  115
# this is the iteration num  116
# this is the iteration num  117
# this is the iteration num  118
# this is the iteration num  119
# this is the iteration num  120
# this is the iteration num  121
# this is the iteration num  122
# this is the iteration num  123
# this is the iteration num  124
# this is the iteration num  125
# this is the iteration num  126
# this is the iteration num  127
# this is the iteration num  128
# this is the iteration num  129
# this is the iteration num  130
# this is the iteration num  131
# this is the iteration num  132
# this is the iteration num  133
# this is the iteration num  134
# this is the iteration num  135
# this is the iteration num  136
# this is the iteration num  137
# this is the iteration num  138
# this is the iteration num  139
# this is the iteration num  140
# this is the iteration num  141
# this is the iteration num  142
# this is the iteration num  143
# this is the iteration num  144
# this is the iteration num  145
# this is the iteration num  146
# this is the iteration num  147
# this is the iteration num  148
# this is the iteration num  149
# this is the iteration num  150
# this is the iteration num  151
# this is the iteration num  152
# this is the iteration num  153
# this is the iteration num  154
# this is the iteration num  155
# this is the iteration num  156
# this is the iteration num  157
# this is the iteration num  158
# this is the iteration num  159
# this is the iteration num  160
# this is the iteration num  161
# this is the iteration num  162
# this is the iteration num  163
# this is the iteration num  164
# this is the iteration num  165
# this is the iteration num  166
# this is the iteration num  167
# this is the iteration num  168
# this is the iteration num  169
# this is the iteration num  170
# this is the iteration num  171
# this is the iteration num  172
# this is the iteration num  173
# this is the iteration num  174
# this is the iteration num  175
# this is the iteration num  176
# this is the iteration num  177
# this is the iteration num  178
# this is the iteration num  179
# this is the iteration num  180
# this is the iteration num  181
# this is the iteration num  182
# this is the iteration num  183
# this is the iteration num  184
# this is the iteration num  185
# this is the iteration num  186
# this is the iteration num  187
# this is the iteration num  188
# this is the iteration num  189
# this is the iteration num  190
# this is the iteration num  191
# this is the iteration num  192
# this is the iteration num  193
# this is the iteration num  194
# this is the iteration num  195
# this is the iteration num  196
# this is the iteration num  197
# this is the iteration num  198
# this is the iteration num  199
# Trained for  ADP
# Entered here
# this is the iteration num  0
# this is the iteration num  1
# this is the iteration num  2
# this is the iteration num  3
# this is the iteration num  4
# this is the iteration num  5
# this is the iteration num  6
# this is the iteration num  7
# this is the iteration num  8
# this is the iteration num  9
# this is the iteration num  10
# this is the iteration num  11
# this is the iteration num  12
# this is the iteration num  13
# this is the iteration num  14
# this is the iteration num  15
# this is the iteration num  16
# this is the iteration num  17
# this is the iteration num  18
# this is the iteration num  19
# this is the iteration num  20
# this is the iteration num  21
# this is the iteration num  22
# this is the iteration num  23
# this is the iteration num  24
# this is the iteration num  25
# this is the iteration num  26
# this is the iteration num  27
# this is the iteration num  28
# this is the iteration num  29
# this is the iteration num  30
# this is the iteration num  31
# this is the iteration num  32
# this is the iteration num  33
# this is the iteration num  34
# this is the iteration num  35
# this is the iteration num  36
# this is the iteration num  37
# this is the iteration num  38
# this is the iteration num  39
# this is the iteration num  40
# this is the iteration num  41
# this is the iteration num  42
# this is the iteration num  43
# this is the iteration num  44
# this is the iteration num  45
# this is the iteration num  46
# this is the iteration num  47
# this is the iteration num  48
# this is the iteration num  49
# this is the iteration num  50
# this is the iteration num  51
# this is the iteration num  52
# this is the iteration num  53
# this is the iteration num  54
# this is the iteration num  55
# this is the iteration num  56
# this is the iteration num  57
# this is the iteration num  58
# this is the iteration num  59
# this is the iteration num  60
# this is the iteration num  61
# this is the iteration num  62
# this is the iteration num  63
# this is the iteration num  64
# this is the iteration num  65
# this is the iteration num  66
# this is the iteration num  67
# this is the iteration num  68
# this is the iteration num  69
# this is the iteration num  70
# this is the iteration num  71
# this is the iteration num  72
# this is the iteration num  73
# this is the iteration num  74
# this is the iteration num  75
# this is the iteration num  76
# this is the iteration num  77
# this is the iteration num  78
# this is the iteration num  79
# this is the iteration num  80
# this is the iteration num  81
# this is the iteration num  82
# this is the iteration num  83
# this is the iteration num  84
# this is the iteration num  85
# this is the iteration num  86
# this is the iteration num  87
# this is the iteration num  88
# this is the iteration num  89
# this is the iteration num  90
# this is the iteration num  91
# this is the iteration num  92
# this is the iteration num  93
# this is the iteration num  94
# this is the iteration num  95
# this is the iteration num  96
# this is the iteration num  97
# this is the iteration num  98
# this is the iteration num  99
# this is the iteration num  100
# this is the iteration num  101
# this is the iteration num  102
# this is the iteration num  103
# this is the iteration num  104
# this is the iteration num  105
# this is the iteration num  106
# this is the iteration num  107
# this is the iteration num  108
# this is the iteration num  109
# this is the iteration num  110
# this is the iteration num  111
# this is the iteration num  112
# this is the iteration num  113
# this is the iteration num  114
# this is the iteration num  115
# this is the iteration num  116
# this is the iteration num  117
# this is the iteration num  118
# this is the iteration num  119
# this is the iteration num  120
# this is the iteration num  121
# this is the iteration num  122
# this is the iteration num  123
# this is the iteration num  124
# this is the iteration num  125
# this is the iteration num  126
# this is the iteration num  127
# this is the iteration num  128
# this is the iteration num  129
# this is the iteration num  130
# this is the iteration num  131
# this is the iteration num  132
# this is the iteration num  133
# this is the iteration num  134
# this is the iteration num  135
# this is the iteration num  136
# this is the iteration num  137
# this is the iteration num  138
# this is the iteration num  139
# this is the iteration num  140
# this is the iteration num  141
# this is the iteration num  142
# this is the iteration num  143
# this is the iteration num  144
# this is the iteration num  145
# this is the iteration num  146
# this is the iteration num  147
# this is the iteration num  148
# this is the iteration num  149
# this is the iteration num  150
# this is the iteration num  151
# this is the iteration num  152
# this is the iteration num  153
# this is the iteration num  154
# this is the iteration num  155
# this is the iteration num  156
# this is the iteration num  157
# this is the iteration num  158
# this is the iteration num  159
# this is the iteration num  160
# this is the iteration num  161
# this is the iteration num  162
# this is the iteration num  163
# this is the iteration num  164
# this is the iteration num  165
# this is the iteration num  166
# this is the iteration num  167
# this is the iteration num  168
# this is the iteration num  169
# this is the iteration num  170
# this is the iteration num  171
# this is the iteration num  172
# this is the iteration num  173
# this is the iteration num  174
# this is the iteration num  175
# this is the iteration num  176
# this is the iteration num  177
# this is the iteration num  178
# this is the iteration num  179
# this is the iteration num  180
# this is the iteration num  181
# this is the iteration num  182
# this is the iteration num  183
# this is the iteration num  184
# this is the iteration num  185
# this is the iteration num  186
# this is the iteration num  187
# this is the iteration num  188
# this is the iteration num  189
# this is the iteration num  190
# this is the iteration num  191
# this is the iteration num  192
# this is the iteration num  193
# this is the iteration num  194
# this is the iteration num  195
# this is the iteration num  196
# this is the iteration num  197
# this is the iteration num  198
# this is the iteration num  199
# Trained for  .
# Entered here
# this is the iteration num  0
# this is the iteration num  1
# this is the iteration num  2
# this is the iteration num  3
# this is the iteration num  4
# this is the iteration num  5
# this is the iteration num  6
# this is the iteration num  7
# this is the iteration num  8
# this is the iteration num  9
# this is the iteration num  10
# this is the iteration num  11
# this is the iteration num  12
# this is the iteration num  13
# this is the iteration num  14
# this is the iteration num  15
# this is the iteration num  16
# this is the iteration num  17
# this is the iteration num  18
# this is the iteration num  19
# this is the iteration num  20
# this is the iteration num  21
# this is the iteration num  22
# this is the iteration num  23
# this is the iteration num  24
# this is the iteration num  25
# this is the iteration num  26
# this is the iteration num  27
# this is the iteration num  28
# this is the iteration num  29
# this is the iteration num  30
# this is the iteration num  31
# this is the iteration num  32
# this is the iteration num  33
# this is the iteration num  34
# this is the iteration num  35
# this is the iteration num  36
# this is the iteration num  37
# this is the iteration num  38
# this is the iteration num  39
# this is the iteration num  40
# this is the iteration num  41
# this is the iteration num  42
# this is the iteration num  43
# this is the iteration num  44
# this is the iteration num  45
# this is the iteration num  46
# this is the iteration num  47
# this is the iteration num  48
# this is the iteration num  49
# this is the iteration num  50
# this is the iteration num  51
# this is the iteration num  52
# this is the iteration num  53
# this is the iteration num  54
# this is the iteration num  55
# this is the iteration num  56
# this is the iteration num  57
# this is the iteration num  58
# this is the iteration num  59
# this is the iteration num  60
# this is the iteration num  61
# this is the iteration num  62
# this is the iteration num  63
# this is the iteration num  64
# this is the iteration num  65
# this is the iteration num  66
# this is the iteration num  67
# this is the iteration num  68
# this is the iteration num  69
# this is the iteration num  70
# this is the iteration num  71
# this is the iteration num  72
# this is the iteration num  73
# this is the iteration num  74
# this is the iteration num  75
# this is the iteration num  76
# this is the iteration num  77
# this is the iteration num  78
# this is the iteration num  79
# this is the iteration num  80
# this is the iteration num  81
# this is the iteration num  82
# this is the iteration num  83
# this is the iteration num  84
# this is the iteration num  85
# this is the iteration num  86
# this is the iteration num  87
# this is the iteration num  88
# this is the iteration num  89
# this is the iteration num  90
# this is the iteration num  91
# this is the iteration num  92
# this is the iteration num  93
# this is the iteration num  94
# this is the iteration num  95
# this is the iteration num  96
# this is the iteration num  97
# this is the iteration num  98
# this is the iteration num  99
# this is the iteration num  100
# this is the iteration num  101
# this is the iteration num  102
# this is the iteration num  103
# this is the iteration num  104
# this is the iteration num  105
# this is the iteration num  106
# this is the iteration num  107
# this is the iteration num  108
# this is the iteration num  109
# this is the iteration num  110
# this is the iteration num  111
# this is the iteration num  112
# this is the iteration num  113
# this is the iteration num  114
# this is the iteration num  115
# this is the iteration num  116
# this is the iteration num  117
# this is the iteration num  118
# this is the iteration num  119
# this is the iteration num  120
# this is the iteration num  121
# this is the iteration num  122
# this is the iteration num  123
# this is the iteration num  124
# this is the iteration num  125
# this is the iteration num  126
# this is the iteration num  127
# this is the iteration num  128
# this is the iteration num  129
# this is the iteration num  130
# this is the iteration num  131
# this is the iteration num  132
# this is the iteration num  133
# this is the iteration num  134
# this is the iteration num  135
# this is the iteration num  136
# this is the iteration num  137
# this is the iteration num  138
# this is the iteration num  139
# this is the iteration num  140
# this is the iteration num  141
# this is the iteration num  142
# this is the iteration num  143
# this is the iteration num  144
# this is the iteration num  145
# this is the iteration num  146
# this is the iteration num  147
# this is the iteration num  148
# this is the iteration num  149
# this is the iteration num  150
# this is the iteration num  151
# this is the iteration num  152
# this is the iteration num  153
# this is the iteration num  154
# this is the iteration num  155
# this is the iteration num  156
# this is the iteration num  157
# this is the iteration num  158
# this is the iteration num  159
# this is the iteration num  160
# this is the iteration num  161
# this is the iteration num  162
# this is the iteration num  163
# this is the iteration num  164
# ...
# this is the iteration num  79
# this is the iteration num  80
# this is the iteration num  81
# this is the iteration num  82
# this is the iteration num  83
# this is the iteration num  84
# this is the iteration num  85
# this is the iteration num  86
# this is the iteration num  87
# this is the iteration num  88
# this is the iteration num  89
# this is the iteration num  90
# this is the iteration num  91
# this is the iteration num  92
# this is the iteration num  93
# this is the iteration num  94
# this is the iteration num  95
# this is the iteration num  96
# this is the iteration num  97
# this is the iteration num  98
# this is the iteration num  99
# this is the iteration num  100
# this is the iteration num  101
# this is the iteration num  102
# this is the iteration num  103
# this is the iteration num  104
# this is the iteration num  105
# this is the iteration num  106
# this is the iteration num  107
# this is the iteration num  108
# this is the iteration num  109
# this is the iteration num  110
# this is the iteration num  111
# this is the iteration num  112
# this is the iteration num  113
# this is the iteration num  114
# this is the iteration num  115
# this is the iteration num  116
# this is the iteration num  117
# this is the iteration num  118
# this is the iteration num  119
# this is the iteration num  120
# this is the iteration num  121
# this is the iteration num  122
# this is the iteration num  123
# this is the iteration num  124
# this is the iteration num  125
# this is the iteration num  126
# this is the iteration num  127
# this is the iteration num  128
# this is the iteration num  129
# this is the iteration num  130
# this is the iteration num  131
# this is the iteration num  132
# this is the iteration num  133
# this is the iteration num  134
# this is the iteration num  135
# this is the iteration num  136
# this is the iteration num  137
# this is the iteration num  138
# this is the iteration num  139
# this is the iteration num  140
# this is the iteration num  141
# this is the iteration num  142
# this is the iteration num  143
# this is the iteration num  144
# this is the iteration num  145
# this is the iteration num  146
# this is the iteration num  147
# this is the iteration num  148
# this is the iteration num  149
# this is the iteration num  150
# this is the iteration num  151
# this is the iteration num  152
# this is the iteration num  153
# this is the iteration num  154
# this is the iteration num  155
# this is the iteration num  156
# this is the iteration num  157
# this is the iteration num  158
# this is the iteration num  159
# this is the iteration num  160
# this is the iteration num  161
# this is the iteration num  162
# this is the iteration num  163
# this is the iteration num  164
# this is the iteration num  165
# this is the iteration num  166
# this is the iteration num  167
# this is the iteration num  168
# this is the iteration num  169
# this is the iteration num  170
# this is the iteration num  171
# this is the iteration num  172
# this is the iteration num  173
# this is the iteration num  174
# this is the iteration num  175
# this is the iteration num  176
# this is the iteration num  177
# this is the iteration num  178
# this is the iteration num  179
# this is the iteration num  180
# this is the iteration num  181
# this is the iteration num  182
# this is the iteration num  183
# this is the iteration num  184
# this is the iteration num  185
# this is the iteration num  186
# this is the iteration num  187
# this is the iteration num  188
# this is the iteration num  189
# this is the iteration num  190
# this is the iteration num  191
# this is the iteration num  192
# this is the iteration num  193
# this is the iteration num  194
# this is the iteration num  195
# this is the iteration num  196
# this is the iteration num  197
# this is the iteration num  198
# this is the iteration num  199
# Trained for  NUM
# Entered here
# this is the iteration num  0
# this is the iteration num  1
# this is the iteration num  2
# this is the iteration num  3
# this is the iteration num  4
# this is the iteration num  5
# this is the iteration num  6
# this is the iteration num  7
# this is the iteration num  8
# this is the iteration num  9
# this is the iteration num  10
# this is the iteration num  11
# this is the iteration num  12
# this is the iteration num  13
# this is the iteration num  14
# this is the iteration num  15
# this is the iteration num  16
# this is the iteration num  17
# this is the iteration num  18
# this is the iteration num  19
# this is the iteration num  20
# this is the iteration num  21
# this is the iteration num  22
# this is the iteration num  23
# this is the iteration num  24
# this is the iteration num  25
# this is the iteration num  26
# this is the iteration num  27
# this is the iteration num  28
# this is the iteration num  29
# this is the iteration num  30
# this is the iteration num  31
# this is the iteration num  32
# this is the iteration num  33
# this is the iteration num  34
# this is the iteration num  35
# this is the iteration num  36
# this is the iteration num  37
# this is the iteration num  38
# this is the iteration num  39
# this is the iteration num  40
# this is the iteration num  41
# this is the iteration num  42
# this is the iteration num  43
# this is the iteration num  44
# this is the iteration num  45
# this is the iteration num  46
# this is the iteration num  47
# this is the iteration num  48
# this is the iteration num  49
# this is the iteration num  50
# this is the iteration num  51
# this is the iteration num  52
# this is the iteration num  53
# this is the iteration num  54
# this is the iteration num  55
# this is the iteration num  56
# this is the iteration num  57
# this is the iteration num  58
# this is the iteration num  59
# this is the iteration num  60
# this is the iteration num  61
# this is the iteration num  62
# this is the iteration num  63
# this is the iteration num  64
# this is the iteration num  65
# this is the iteration num  66
# this is the iteration num  67
# this is the iteration num  68
# this is the iteration num  69
# this is the iteration num  70
# this is the iteration num  71
# this is the iteration num  72
# this is the iteration num  73
# this is the iteration num  74
# this is the iteration num  75
# this is the iteration num  76
# this is the iteration num  77
# this is the iteration num  78
# this is the iteration num  79
# this is the iteration num  80
# this is the iteration num  81
# this is the iteration num  82
# this is the iteration num  83
# this is the iteration num  84
# this is the iteration num  85
# this is the iteration num  86
# this is the iteration num  87
# this is the iteration num  88
# this is the iteration num  89
# this is the iteration num  90
# this is the iteration num  91
# this is the iteration num  92
# this is the iteration num  93
# this is the iteration num  94
# this is the iteration num  95
# this is the iteration num  96
# this is the iteration num  97
# this is the iteration num  98
# this is the iteration num  99
# this is the iteration num  100
# this is the iteration num  101
# this is the iteration num  102
# this is the iteration num  103
# this is the iteration num  104
# this is the iteration num  105
# this is the iteration num  106
# this is the iteration num  107
# this is the iteration num  108
# this is the iteration num  109
# this is the iteration num  110
# this is the iteration num  111
# this is the iteration num  112
# this is the iteration num  113
# this is the iteration num  114
# this is the iteration num  115
# this is the iteration num  116
# this is the iteration num  117
# this is the iteration num  118
# this is the iteration num  119
# this is the iteration num  120
# this is the iteration num  121
# this is the iteration num  122
# this is the iteration num  123
# this is the iteration num  124
# this is the iteration num  125
# this is the iteration num  126
# this is the iteration num  127
# this is the iteration num  128
# this is the iteration num  129
# this is the iteration num  130
# this is the iteration num  131
# this is the iteration num  132
# this is the iteration num  133
# this is the iteration num  134
# this is the iteration num  135
# this is the iteration num  136
# this is the iteration num  137
# this is the iteration num  138
# this is the iteration num  139
# this is the iteration num  140
# this is the iteration num  141
# this is the iteration num  142
# this is the iteration num  143
# this is the iteration num  144
# this is the iteration num  145
# this is the iteration num  146
# this is the iteration num  147
# this is the iteration num  148
# this is the iteration num  149
# this is the iteration num  150
# this is the iteration num  151
# this is the iteration num  152
# this is the iteration num  153
# this is the iteration num  154
# this is the iteration num  155
# this is the iteration num  156
# this is the iteration num  157
# this is the iteration num  158
# this is the iteration num  159
# this is the iteration num  160
# this is the iteration num  161
# this is the iteration num  162
# this is the iteration num  163
# this is the iteration num  164
# this is the iteration num  165
# this is the iteration num  166
# this is the iteration num  167
# this is the iteration num  168
# this is the iteration num  169
# this is the iteration num  170
# this is the iteration num  171
# this is the iteration num  172
# this is the iteration num  173
# this is the iteration num  174
# this is the iteration num  175
# this is the iteration num  176
# this is the iteration num  177
# this is the iteration num  178
# this is the iteration num  179
# this is the iteration num  180
# this is the iteration num  181
# this is the iteration num  182
# this is the iteration num  183
# this is the iteration num  184
# this is the iteration num  185
# this is the iteration num  186
# this is the iteration num  187
# this is the iteration num  188
# this is the iteration num  189
# this is the iteration num  190
# this is the iteration num  191
# this is the iteration num  192
# this is the iteration num  193
# this is the iteration num  194
# this is the iteration num  195
# this is the iteration num  196
# this is the iteration num  197
# this is the iteration num  198
# this is the iteration num  199
# Trained for  NOUN
# Entered here
# this is the iteration num  0
# this is the iteration num  1
# this is the iteration num  2
# this is the iteration num  3
# this is the iteration num  4
# this is the iteration num  5
# this is the iteration num  6
# this is the iteration num  7
# this is the iteration num  8
# this is the iteration num  9
# this is the iteration num  10
# this is the iteration num  11
# this is the iteration num  12
# this is the iteration num  13
# this is the iteration num  14
# this is the iteration num  15
# this is the iteration num  16
# this is the iteration num  17
# this is the iteration num  18
# this is the iteration num  19
# this is the iteration num  20
# this is the iteration num  21
# this is the iteration num  22
# this is the iteration num  23
# this is the iteration num  24
# this is the iteration num  25
# this is the iteration num  26
# this is the iteration num  27
# this is the iteration num  28
# this is the iteration num  29
# this is the iteration num  30
# this is the iteration num  31
# this is the iteration num  32
# this is the iteration num  33
# this is the iteration num  34
# this is the iteration num  35
# this is the iteration num  36
# this is the iteration num  37
# this is the iteration num  38
# this is the iteration num  39
# this is the iteration num  40
# this is the iteration num  41
# this is the iteration num  42
# this is the iteration num  43
# this is the iteration num  44
# this is the iteration num  45
# this is the iteration num  46
# this is the iteration num  47
# this is the iteration num  48
# this is the iteration num  49
# this is the iteration num  50
# this is the iteration num  51
# this is the iteration num  52
# this is the iteration num  53
# this is the iteration num  54
# this is the iteration num  55
# this is the iteration num  56
# this is the iteration num  57
# this is the iteration num  58
# this is the iteration num  59
# this is the iteration num  60
# this is the iteration num  61
# this is the iteration num  62
# this is the iteration num  63
# this is the iteration num  64
# this is the iteration num  65
# this is the iteration num  66
# this is the iteration num  67
# this is the iteration num  68
# this is the iteration num  69
# this is the iteration num  70
# this is the iteration num  71
# this is the iteration num  72
# this is the iteration num  73
# this is the iteration num  74
# this is the iteration num  75
# this is the iteration num  76
# this is the iteration num  77
# this is the iteration num  78
# this is the iteration num  79
# this is the iteration num  80
# this is the iteration num  81
# this is the iteration num  82
# this is the iteration num  83
# this is the iteration num  84
# this is the iteration num  85
# this is the iteration num  86
# this is the iteration num  87
# this is the iteration num  88
# this is the iteration num  89
# this is the iteration num  90
# this is the iteration num  91
# this is the iteration num  92
# this is the iteration num  93
# this is the iteration num  94
# this is the iteration num  95
# this is the iteration num  96
# this is the iteration num  97
# this is the iteration num  98
# this is the iteration num  99
# this is the iteration num  100
# this is the iteration num  101
# this is the iteration num  102
# this is the iteration num  103
# this is the iteration num  104
# this is the iteration num  105
# this is the iteration num  106
# this is the iteration num  107
# this is the iteration num  108
# this is the iteration num  109
# this is the iteration num  110
# this is the iteration num  111
# this is the iteration num  112
# this is the iteration num  113
# this is the iteration num  114
# this is the iteration num  115
# this is the iteration num  116
# this is the iteration num  117
# this is the iteration num  118
# this is the iteration num  119
# this is the iteration num  120
# this is the iteration num  121
# this is the iteration num  122
# this is the iteration num  123
# this is the iteration num  124
# this is the iteration num  125
# this is the iteration num  126
# this is the iteration num  127
# this is the iteration num  128
# this is the iteration num  129
# this is the iteration num  130
# this is the iteration num  131
# this is the iteration num  132
# this is the iteration num  133
# this is the iteration num  134
# this is the iteration num  135
# this is the iteration num  136
# this is the iteration num  137
# this is the iteration num  138
# this is the iteration num  139
# this is the iteration num  140
# this is the iteration num  141
# this is the iteration num  142
# this is the iteration num  143
# this is the iteration num  144
# this is the iteration num  145
# this is the iteration num  146
# this is the iteration num  147
# this is the iteration num  148
# this is the iteration num  149
# this is the iteration num  150
# this is the iteration num  151
# this is the iteration num  152
# this is the iteration num  153
# this is the iteration num  154
# this is the iteration num  155
# this is the iteration num  156
# this is the iteration num  157
# this is the iteration num  158
# this is the iteration num  159
# this is the iteration num  160
# this is the iteration num  161
# this is the iteration num  162
# this is the iteration num  163
# this is the iteration num  164
# this is the iteration num  165
# this is the iteration num  166
# this is the iteration num  167
# this is the iteration num  168
# this is the iteration num  169
# this is the iteration num  170
# this is the iteration num  171
# this is the iteration num  172
# this is the iteration num  173
# this is the iteration num  174
# this is the iteration num  175
# this is the iteration num  176
# this is the iteration num  177
# this is the iteration num  178
# this is the iteration num  179
# this is the iteration num  180
# this is the iteration num  181
# this is the iteration num  182
# this is the iteration num  183
# this is the iteration num  184
# this is the iteration num  185
# this is the iteration num  186
# this is the iteration num  187
# this is the iteration num  188
# this is the iteration num  189
# this is the iteration num  190
# this is the iteration num  191
# this is the iteration num  192
# this is the iteration num  193
# this is the iteration num  194
# this is the iteration num  195
# this is the iteration num  196
# this is the iteration num  197
# this is the iteration num  198
# this is the iteration num  199
# Trained for  ADJ

# %%
unigram_count
# Out:
# {'The': 6430,
#  'Fulton': 17,
#  'County': 81,
#  'Grand': 16,
#  'Jury': 3,
#  'said': 1177,
#  'Friday': 57,
#  'an': 3108,
#  'investigation': 39,
#  'of': 32644,
#  "Atlanta's": 4,
#  'recent': 160,
#  'primary': 91,
#  'election': 72,
#  'produced': 88,
#  '``': 6160,
#  'no': 1449,
#  'evidence': 195,
#  "''": 6119,
#  'that': 8741,
#  'any': 1140,
#  'irregularities': 7,
#  'took': 289,
#  'place': 426,
#  '.': 39534,
#  'jury': 57,
#  'further': 179,
#  'in': 17279,
#  'term-end': 1,
#  'presentments': 1,
#  'the': 54761,
#  'City': 128,
#  'Executive': 9,
#  'Committee': 87,
#  ',': 48492,
#  'which': 3232,
#  'had': 3487,
#  'over-all': 34,
#  'charge': 112,
#  'deserves': 15,
#  'praise': 16,
#  'and': 23598,
#  'thanks': 21,
#  'Atlanta': 35,
#  'for': 7814,
#  'manner': 111,
#  'was': 7313,
#  'conducted': 55,
#  'September-October': 1,
#  'term': 78,
#  'been': 2056,
#  'charged': 55,
#  'by': 4731,
#  'Superior': 16,
#  'Court': 108,
#  'Judge': 39,
#  'Durwood': 1,
#  'Pye': 1,
#  'to': 22030,
#  'investigate': 8,
#  'reports': 75,
#  'possible': 343,
#  'hard-fought': 2,
#  'won': 63,
#  'Mayor-nominate': 1,
#  'Ivan': 4,
#  'Allen': 20,
#  'Jr.': 74,
#  'Only': 84,
#  'a': 18351,
#  'relative': 44,
#  'handful': 12,
#  'such': 1109,
#  'received': 149,
#  'considering': 34,
#  'widespread': 29,
#  'interest': 302,
#  'number': 455,
#  'voters': 18,
#  'size': 123,
#  'this': 3496,
#  'city': 241,
#  'it': 5292,
#  'did': 733,
#  'find': 328,
#  'many': 850,
#  "Georgia's": 9,
#  'registration': 21,
#  'laws': 82,
#  'are': 4141,
#  'outmoded': 4,
#  'or': 3738,
#  'inadequate': 31,
#  'often': 326,
#  'ambiguous': 17,
#  'It': 1657,
#  'recommended': 46,
#  'legislators': 16,
#  'act': 156,
#  'have': 3353,
#  'these': 1139,
#  'studied': 63,
#  'revised': 14,
#  'end': 340,
#  'modernizing': 4,
#  'improving': 16,
#  'them': 1377,
#  'grand': 28,
#  'commented': 18,
#  'on': 5320,
#  'other': 1434,
#  'topics': 10,
#  'among': 277,
#  'purchasing': 14,
#  'departments': 24,
#  'well': 667,
#  'operated': 25,
#  'follow': 76,
#  'generally': 115,
#  'accepted': 86,
#  'practices': 49,
#  'inure': 2,
#  'best': 311,
#  'both': 567,
#  'governments': 51,
#  'Merger': 1,
#  'proposed': 81,
#  'However': 163,
#  'believes': 41,
#  'two': 1137,
#  'offices': 34,
#  'should': 805,
#  'be': 5702,
#  'combined': 39,
#  'achieve': 51,
#  'greater': 175,
#  'efficiency': 48,
#  'reduce': 62,
#  'cost': 216,
#  'administration': 101,
#  'Purchasing': 3,
#  'Department': 163,
#  'is': 9592,
#  'lacking': 26,
#  'experienced': 47,
#  'clerical': 9,
#  'personnel': 64,
#  'as': 5890,
#  'result': 238,
#  'policies': 66,
#  'urged': 31,
#  'take': 448,
#  'steps': 86,
#  'remedy': 13,
#  'problem': 294,
#  'Implementation': 3,
#  'automobile': 41,
#  'title': 46,
#  'law': 266,
#  'also': 947,
#  'outgoing': 8,
#  'next': 283,
#  'Legislature': 27,
#  'provide': 209,
#  'enabling': 13,
#  'funds': 90,
#  're-set': 1,
#  'effective': 125,
#  'date': 91,
#  'so': 1381,
#  'orderly': 14,
#  'implementation': 5,
#  'may': 1263,
#  'effected': 12,
#  'swipe': 2,
#  'at': 4066,
#  'State': 262,
#  'Welfare': 7,
#  "Department's": 15,
#  'handling': 37,
#  'federal': 111,
#  'granted': 51,
#  'child': 180,
#  'welfare': 46,
#  'services': 127,
#  'foster': 4,
#  'homes': 61,
#  'This': 1072,
#  'one': 2420,
#  'major': 221,
#  'items': 66,
#  'general': 306,
#  'assistance': 83,
#  'program': 370,
#  'but': 2411,
#  'has': 2346,
#  'seen': 212,
#  'fit': 63,
#  'distribute': 6,
#  'through': 764,
#  'all': 2220,
#  'counties': 28,
#  'state': 530,
#  'with': 5918,
#  'exception': 38,
#  'receives': 20,
#  'none': 73,
#  'money': 213,
#  'jurors': 4,
#  'they': 2264,
#  'realize': 61,
#  'proportionate': 9,
#  'distribution': 82,
#  'might': 534,
#  'disable': 1,
#  'our': 1040,
#  'less': 379,
#  'populous': 5,
#  'Nevertheless': 38,
#  'we': 1721,
#  'feel': 146,
#  'future': 201,
#  'receive': 72,
#  'some': 1244,
#  'portion': 58,
#  'available': 236,
#  'Failure': 4,
#  'do': 993,
#  'will': 2079,
#  'continue': 100,
#  'disproportionate': 2,
#  'burden': 40,
#  'taxpayers': 20,
#  "ordinary's": 1,
#  'court': 116,
#  'under': 579,
#  'fire': 119,
#  'its': 1617,
#  'appointment': 24,
#  'appraisers': 1,
#  'guardians': 4,
#  'administrators': 5,
#  'awarding': 3,
#  'fees': 27,
#  'compensation': 17,
#  'Wards': 1,
#  'protected': 28,
#  'found': 444,
#  'incorporated': 12,
#  'into': 1404,
#  'operating': 81,
#  'procedures': 61,
#  'recommendations': 21,
#  'previous': 79,
#  'juries': 1,
#  'Bar': 7,
#  'Association': 85,
#  'interim': 10,
#  'citizens': 74,
#  'committee': 77,
#  'These': 333,
#  'actions': 62,
#  'serve': 95,
#  'protect': 33,
#  'fact': 419,
#  'effect': 199,
#  "court's": 2,
#  'wards': 2,
#  'from': 3619,
#  'undue': 12,
#  'costs': 171,
#  'appointed': 39,
#  'elected': 29,
#  'servants': 19,
#  'unmeritorious': 1,
#  'criticisms': 10,
#  'Regarding': 1,
#  'new': 984,
#  'multi-million-dollar': 2,
#  'airport': 10,
#  'when': 1403,
#  'management': 85,
#  'takes': 80,
#  'Jan.': 20,
#  '1': 526,
#  'eliminate': 25,
#  'political': 249,
#  'influences': 14,
#  'not': 3803,
#  'elaborate': 26,
#  'added': 148,
#  'there': 1508,
#  'periodic': 8,
#  'surveillance': 6,
#  'pricing': 7,
#  'concessionaires': 6,
#  'purpose': 138,
#  'keeping': 47,
#  'prices': 61,
#  'reasonable': 59,
#  'Ask': 11,
#  'jail': 14,
#  'deputies': 12,
#  'On': 314,
#  'matters': 59,
#  ':': 1617,
#  '(': 2350,
#  ')': 2381,
#  'Four': 30,
#  'additional': 105,
#  'employed': 47,
#  'Jail': 4,
#  'doctor': 67,
#  'medical': 116,
#  'intern': 1,
#  'extern': 1,
#  'night': 290,
#  'weekend': 24,
#  'duty': 43,
#  '2': 444,
#  'work': 664,
#  'officials': 55,
#  'pass': 72,
#  'legislation': 44,
#  'permit': 68,
#  'establishment': 49,
#  'fair': 56,
#  'equitable': 11,
#  'pension': 10,
#  'plan': 185,
#  'employes': 15,
#  'praised': 12,
#  'operation': 104,
#  'Police': 21,
#  'Tax': 9,
#  "Commissioner's": 1,
#  'Office': 41,
#  'Bellwood': 1,
#  'Alpharetta': 1,
#  'prison': 32,
#  'farms': 14,
#  'Grady': 5,
#  'Hospital': 35,
#  'Health': 16,
#  'Mayor': 30,
#  'William': 125,
#  'B.': 76,
#  'Hartsfield': 5,
#  'filed': 31,
#  'suit': 36,
#  'divorce': 23,
#  'his': 4843,
#  'wife': 166,
#  'Pearl': 6,
#  'Williams': 29,
#  'His': 394,
#  'petition': 15,
#  'mental': 34,
#  'cruelty': 11,
#  'couple': 84,
#  'married': 78,
#  'Aug.': 25,
#  '1913': 12,
#  'They': 635,
#  'son': 93,
#  'Berry': 6,
#  'daughter': 58,
#  'Mrs.': 470,
#  'J.': 118,
#  'M.': 59,
#  'Cheshire': 1,
#  'Griffin': 4,
#  'Attorneys': 3,
#  'mayor': 5,
#  'amicable': 1,
#  'property': 145,
#  'settlement': 23,
#  'agreed': 66,
#  'upon': 431,
#  'listed': 41,
#  "mayor's": 4,
#  'occupation': 21,
#  'attorney': 24,
#  'age': 192,
#  '71': 10,
#  "wife's": 9,
#  '74': 6,
#  'birth': 62,
#  'Opelika': 2,
#  'Ala.': 7,
#  'lived': 78,
#  'together': 211,
#  'man': 844,
#  'more': 1897,
#  'than': 1621,
#  'year': 614,
#  'home': 434,
#  '637': 1,
#  'E.': 85,
#  'Pelham': 5,
#  'Rd.': 3,
#  'Aj': 116,
#  'Henry': 79,
#  'L.': 53,
#  'Bowden': 2,
#  'brief': 60,
#  'interlude': 3,
#  'since': 404,
#  '1937': 9,
#  'career': 61,
#  'goes': 75,
#  'back': 604,
#  'council': 27,
#  '1923': 7,
#  'present': 351,
#  'office': 181,
#  'expires': 1,
#  'He': 1955,
#  'succeeded': 27,
#  'who': 1947,
#  'became': 212,
#  'candidate': 31,
#  'Sept.': 34,
#  '13': 49,
#  'after': 678,
#  'announced': 76,
#  'he': 4732,
#  'would': 2088,
#  'run': 171,
#  'reelection': 2,
#  'Georgia': 46,
#  'Republicans': 29,
#  'getting': 119,
#  'strong': 164,
#  'encouragement': 13,
#  'enter': 73,
#  '1962': 35,
#  "governor's": 9,
#  'race': 96,
#  'top': 171,
#  'official': 68,
#  'Wednesday': 31,
#  'Robert': 80,
#  'Snodgrass': 2,
#  'GOP': 13,
#  'chairman': 48,
#  'meeting': 131,
#  'held': 212,
#  'Tuesday': 55,
#  'Blue': 28,
#  'Ridge': 6,
#  'brought': 193,
#  'enthusiastic': 21,
#  'responses': 26,
#  'audience': 111,
#  'Party': 21,
#  'Chairman': 18,
#  'James': 96,
#  'W.': 81,
#  'Dorsey': 1,
#  'enthusiasm': 25,
#  'picking': 10,
#  'up': 1340,
#  'rally': 8,
#  '8': 106,
#  'Savannah': 9,
#  'newly': 26,
#  'Texas': 68,
#  'Sen.': 30,
#  'John': 317,
#  'Tower': 1,
#  'featured': 7,
#  'speaker': 23,
#  'In': 1656,
#  'warned': 20,
#  'entering': 21,
#  'governor': 44,
#  'force': 188,
#  'petitions': 7,
#  'out': 1473,
#  'voting': 28,
#  'precincts': 5,
#  'obtain': 42,
#  'signatures': 5,
#  'registered': 17,
#  'Despite': 38,
#  'warning': 36,
#  'unanimous': 5,
#  'vote': 74,
#  'according': 108,
#  'attended': 35,
#  'When': 476,
#  'crowd': 42,
#  'asked': 273,
#  'whether': 234,
#  'wanted': 152,
#  'wait': 46,
#  'make': 637,
#  'voted': 26,
#  '--': 2783,
#  'were': 2654,
#  'dissents': 2,
#  'largest': 49,
#  'hurdle': 1,
#  'face': 237,
#  'says': 181,
#  'before': 743,
#  'making': 213,
#  'first': 1098,
#  'alternative': 33,
#  'courses': 57,
#  'must': 908,
#  'taken': 248,
#  'Five': 34,
#  'per': 370,
#  'cent': 151,
#  'each': 685,
#  'county': 68,
#  'sign': 78,
#  'requesting': 8,
#  'allowed': 81,
#  'names': 77,
#  'candidates': 38,
#  'ballot': 12,
#  'hold': 135,
#  'unit': 93,
#  'system': 386,
#  'party': 165,
#  'opposes': 2,
#  'platform': 67,
#  'Sam': 61,
#  'Caldwell': 3,
#  'Highway': 6,
#  'public': 387,
#  'relations': 92,
#  'director': 70,
#  'resigned': 8,
#  'Lt.': 8,
#  'Gov.': 19,
#  'Garland': 8,
#  "Byrd's": 3,
#  'campaign': 76,
#  "Caldwell's": 2,
#  'resignation': 7,
#  'expected': 169,
#  'time': 1252,
#  'Rob': 9,
#  'Ledford': 1,
#  'Gainesville': 1,
#  'assistant': 22,
#  'three': 486,
#  'years': 838,
#  'gubernatorial': 7,
#  'starts': 29,
#  'become': 332,
#  'coordinator': 5,
#  'Byrd': 9,
#  'wind': 44,
#  '1961': 134,
#  'session': 78,
#  'Monday': 63,
#  'head': 276,
#  'where': 712,
#  'highway': 31,
#  'bond': 43,
#  'approved': 37,
#  'shortly': 21,
#  'Before': 56,
#  'adjournment': 4,
#  'afternoon': 79,
#  'Senate': 57,
#  'approve': 14,
#  'study': 230,
#  'allotted': 9,
#  'rural': 46,
#  'urban': 41,
#  'areas': 234,
#  'determine': 87,
#  'what': 1129,
#  'adjustments': 20,
#  'made': 938,
#  'Vandiver': 6,
#  'traditional': 77,
#  'visit': 91,
#  'chambers': 8,
#  'toward': 297,
#  'likely': 148,
#  'mention': 43,
#  '$100': 12,
#  'million': 196,
#  'issue': 143,
#  'earlier': 133,
#  'priority': 18,
#  'item': 52,
#  'Construction': 6,
#  'bonds': 47,
#  'Meanwhile': 19,
#  'learned': 102,
#  'very': 640,
#  'near': 153,
#  'being': 593,
#  'ready': 109,
#  '$30': 1,
#  'worth': 81,
#  'reconstruction': 8,
#  'go': 435,
#  'courts': 42,
#  'friendly': 51,
#  'test': 107,
#  'validity': 14,
#  'then': 781,
#  'sales': 120,
#  'begin': 72,
#  'contracts': 20,
#  'let': 206,
#  'repair': 17,
#  'most': 975,
#  'heavily': 51,
#  'traveled': 21,
#  'highways': 14,
#  'A': 1148,
#  'source': 89,
#  '$3': 3,
#  '$4': 5,
#  'Rural': 8,
#  'Roads': 4,
#  'Authority': 10,
#  'road': 149,
#  'construction': 88,
#  'revolving': 6,
#  'fund': 42,
#  'department': 56,
#  'apparently': 96,
#  'intends': 6,
#  'issued': 47,
#  'every': 372,
#  'old': 437,
#  'ones': 97,
#  'paid': 129,
#  'off': 455,
#  'tax': 189,
#  'authorities': 33,
#  'opened': 93,
#  '1958': 91,
#  'battle': 69,
#  'against': 494,
#  'issuance': 7,
#  '$50': 7,
#  'roads': 53,
#  'Marvin': 9,
#  'told': 288,
#  'Constitution': 38,
#  'however': 362,
#  'consulted': 16,
#  'yet': 228,
#  'about': 1411,
#  'plans': 98,
#  'Schley': 1,
#  'Rep.': 13,
#  'D.': 64,
#  'offer': 70,
#  'resolution': 61,
#  'House': 187,
#  'rescind': 2,
#  "body's": 3,
#  'action': 273,
#  'itself': 280,
#  '$10': 7,
#  'day': 488,
#  'increase': 192,
#  'expense': 48,
#  'allowances': 25,
#  'Sunday': 94,
#  'research': 129,
#  'done': 254,
#  'quickie': 1,
#  'can': 1578,
#  'repealed': 3,
#  'outright': 9,
#  'notice': 42,
#  'given': 339,
#  'reconsideration': 4,
#  'sought': 47,
#  'While': 108,
#  'emphasizing': 2,
#  'technical': 111,
#  'details': 51,
#  'fully': 77,
#  'worked': 107,
#  'seek': 66,
#  'set': 352,
#  'aside': 43,
#  'privilege': 18,
#  '87-31': 1,
#  'similar': 141,
#  'passed': 120,
#  '29-5': 1,
#  'As': 472,
#  'word': 222,
#  'offered': 70,
#  'pointed': 58,
#  'last': 525,
#  'November': 70,
#  'rejected': 31,
#  'constitutional': 24,
#  'amendment': 17,
#  'allow': 65,
#  'pay': 155,
#  'raises': 16,
#  'sessions': 24,
#  'veteran': 26,
#  'Jackson': 29,
#  'legislator': 7,
#  'ask': 88,
#  'aid': 123,
#  'education': 171,
#  'something': 282,
#  'consistently': 18,
#  'opposed': 41,
#  'past': 238,
#  'Mac': 1,
#  'Barber': 5,
#  'Commerce': 40,
#  'asking': 57,
#  'endorse': 6,
#  'increased': 137,
#  'support': 175,
#  'provided': 126,
#  'expended': 12,
#  '13th': 6,
#  'members': 305,
#  'congressional': 13,
#  'delegation': 11,
#  'Washington': 203,
#  'like': 843,
#  'see': 537,
#  'But': 1035,
#  'congressmen': 8,
#  'specifically': 35,
#  'him': 1678,
#  'tossed': 21,
#  'hopper': 2,
#  'formally': 17,
#  'read': 131,
#  'event': 80,
#  'Congress': 150,
#  'does': 420,
#  'Board': 68,
#  'Education': 39,
#  'directed': 63,
#  'give': 313,
#  'teacher': 64,
#  'Colquitt': 2,
#  'After': 205,
#  'long': 529,
#  'hot': 88,
#  'controversy': 26,
#  'Miller': 19,
#  'school': 381,
#  'superintendent': 13,
#  'policeman': 13,
#  'put': 330,
#  'coolest': 3,
#  'I': 3113,
#  'ever': 252,
#  'saw': 218,
#  'Harry': 34,
#  'Davis': 27,
#  'agriculture': 12,
#  'defeated': 14,
#  'Felix': 29,
#  'Bush': 4,
#  'principal': 81,
#  'Democratic': 68,
#  '1,119': 1,
#  'votes': 20,
#  "Saturday's": 3,
#  'got': 270,
#  '402': 1,
#  'Ordinary': 5,
#  'Carey': 5,
#  'armed': 30,
#  'pistol': 11,
#  'stood': 131,
#  'polls': 9,
#  'insure': 22,
#  'order': 338,
#  'calmest': 1,
#  'Policeman': 1,
#  'Tom': 34,
#  'Being': 17,
#  'just': 534,
#  'church': 190,
#  "didn't": 189,
#  'smell': 25,
#  'drop': 43,
#  'liquor': 35,
#  'bit': 69,
#  'trouble': 95,
#  'leading': 57,
#  'quiet': 56,
#  'marked': 78,
#  'anonymous': 12,
#  'midnight': 15,
#  'phone': 34,
#  'calls': 67,
#  'veiled': 6,
#  'threats': 9,
#  'violence': 39,
#  'former': 121,
#  'George': 101,
#  'P.': 43,
#  'Callan': 1,
#  'shot': 75,
#  'himself': 439,
#  'death': 228,
#  'March': 95,
#  '18': 55,
#  'four': 293,
#  'days': 310,
#  'post': 53,
#  'dispute': 34,
#  'board': 155,
#  'During': 125,
#  'reportedly': 8,
#  'telephone': 56,
#  'too': 603,
#  'subjected': 22,
#  'soon': 138,
#  'scheduled': 35,
#  'Many': 99,
#  'local': 268,
#  'feared': 12,
#  'carry': 74,
#  'gun': 67,
#  'promised': 32,
#  'Sheriff': 5,
#  'Tabb': 1,
#  'ordinary': 64,
#  'good': 639,
#  'promise': 34,
#  'Everything': 18,
#  'went': 327,
#  'real': 215,
#  'smooth': 34,
#  'sheriff': 14,
#  'There': 691,
#  "wasn't": 66,
#  'Austin': 18,
#  'approval': 49,
#  'Price': 8,
#  "Daniel's": 1,
#  'abandoned': 24,
#  'seemed': 216,
#  'certain': 273,
#  'Thursday': 31,
#  'despite': 60,
#  'adamant': 4,
#  'protests': 7,
#  'bankers': 11,
#  'Daniel': 14,
#  'personally': 31,
#  'led': 112,
#  'fight': 79,
#  'measure': 82,
#  'watered': 5,
#  'down': 564,
#  'considerably': 43,
#  'rejection': 11,
#  'Legislatures': 1,
#  'hearing': 64,
#  'Revenue': 15,
#  'Taxation': 2,
#  'Under': 55,
#  'rules': 72,
#  'automatically': 31,
#  'subcommittee': 4,
#  'week': 224,
#  'questions': 126,
#  'taunted': 2,
#  'appearing': 15,
#  'witnesses': 17,
#  'left': 358,
#  'little': 576,
#  'doubt': 92,
#  'recommend': 21,
#  'passage': 47,
#  'termed': 13,
#  'extremely': 49,
#  'conservative': 30,
#  'estimate': 29,
#  'produce': 79,
#  '17': 41,
#  'dollars': 81,
#  'help': 247,
#  'erase': 1,
#  'anticipated': 20,
#  'deficit': 11,
#  '63': 5,
#  'current': 97,
#  'fiscal': 116,
#  '31': 38,
#  'merely': 123,
#  'means': 278,
#  'enforcing': 4,
#  'escheat': 2,
#  'books': 78,
#  'republic': 8,
#  'permits': 27,
#  'over': 947,
#  'bank': 48,
#  'accounts': 34,
#  'stocks': 17,
#  'personal': 181,
#  'persons': 113,
#  'missing': 23,
#  'seven': 74,
#  'bill': 74,
#  'drafted': 4,
#  'banks': 17,
#  'insurance': 38,
#  'firms': 54,
#  'pipeline': 4,
#  'companies': 85,
#  'corporations': 21,
#  'report': 146,
#  'treasurer': 10,
#  'cannot': 245,
#  'enforced': 19,
#  'now': 833,
#  'because': 671,
#  'almost': 329,
#  'impossible': 69,
#  'locate': 11,
#  'declared': 61,
#  'Dewey': 3,
#  'Lawrence': 39,
#  'Tyler': 2,
#  'lawyer': 36,
#  'representing': 26,
#  'Bankers': 4,
#  'sounded': 21,
#  'opposition': 44,
#  'keynote': 4,
#  'violate': 7,
#  'their': 2200,
#  'contractual': 7,
#  'obligations': 22,
#  'depositors': 1,
#  'undermine': 8,
#  'confidence': 52,
#  'customers': 34,
#  'If': 627,
#  'you': 1701,
#  'destroy': 45,
#  'economy': 75,
#  'You': 293,
#  'circulation': 15,
#  'millions': 47,
#  'Charles': 79,
#  'Hughes': 26,
#  'Sherman': 29,
#  'sponsor': 14,
#  'failure': 82,
#  'enact': 6,
#  'amount': 166,
#  'gift': 27,
#  "taxpayers'": 2,
#  'pockets': 12,
#  'contention': 9,
#  'denied': 45,
#  'several': 303,
#  'including': 160,
#  'Scott': 15,
#  'Hudson': 51,
#  'Gaynor': 1,
#  'Jones': 59,
#  'Houston': 24,
#  'Brady': 1,
#  'Harlingen': 1,
#  'Howard': 31,
#  'Cox': 5,
#  'argued': 26,
#  'probably': 198,
#  'unconstitutional': 1,
#  'impair': 4,
#  'complained': 21,
#  'enough': 329,
#  'introduced': 50,
#  'only': 1385,
#  'Senators': 5,
#  'unanimously': 9,
#  'Parkhouse': 5,
#  'Dallas': 58,
#  'authorizing': 5,
#  'schools': 187,
#  'deaf': 10,
#  'designed': 105,
#  'special': 223,
#  'schooling': 5,
#  ...}

# %%
def get_pred_tags(sentence):
    ans = []
    max_val = 0
    tag_temp = "NOUN"
    for iter, wordtag_pair in enumerate(sentence):
        word = wordtag_pair[0]
        tag = wordtag_pair[1]
        appender = []
        x = get_features(sentence, iter)
        for t, it in x.items():
            appender.append(it)
        for tag in train_tags:
            temp = np.dot(appender, W[tag])
            if temp > max_val:
                tag_temp = tag
        ans.append(tag_temp)
    return ans

# %%
def test():
    score = 0
    tcount = 0
    for iter, sentence in enumerate(word_tag_list_test):
        ans = get_pred_tags(sentence)
#         print("this is the ans", ans)
        tcount += len(sentence)
        for i in range(len(sentence)):
            if ans[i] == sentence[i][1]:
                score += 1.8
#     print("this is the score", score)
#     print("this is the tcount", tcount)
    acc = (score / tcount) * 100
    print(acc)

# %%
test()
# Out:
# 55.47354389526649
