# %% [markdown]
# # Naive Bayes Implementation

# %% [markdown]
# ## Imports

# %%
import sys, re, collections, pickle
import os
import matplotlib.pyplot as plt
import pprint
import numpy as np
from copy import deepcopy

# %% [markdown]
# # Data Loading
#
# - ```save()``` : Takes an object and makes a pickle file for it
# - ```load()``` : Loads objects from pickle files
# - ```load_data_test```: Gets the data from the

# %%
PATH_DATA_TRAIN = '../Data/train.txt'
PATH_DATA_TEST = '../Data/dev.txt'

def save(obj, name):
    if 'files' not in os.listdir():
        os.mkdir('files')
    with open('files/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load(name):
    try:
        with open('files/' + name + '.pkl', 'rb') as f:
            return pickle.load(f)
    except:
        return None
       
def load_data_test():
        training_lines = load('training_lines')
        testing_lines = load('testing_lines')
        
        if not (training_lines and testing_lines):
            training_lines = []
            testing_lines = []
            temp = []
            temp1 = []
            f = open(PATH_DATA_TRAIN, 'r')
            k = open(PATH_DATA_TEST, 'r')
            data = f.read()
            data1 = k.read()
            f.close()
            k.close()
            raw_data = data.split('\n')
            raw_data1 = data1.split('\n')
            for i in raw_data:
                if i == '':
                    training_lines.append(temp)
                    temp = []
                else:
                    temp.append(i)
            save(training_lines, 'training_lines')
            for j in raw_data1:
                if j == '':
                    testing_lines.append(temp1)
                    temp1 = []
                else:
                    temp1.append(j)
            save(testing_lines, 'testing_lines')

# %%
load_data_test()
training_lines = load('training_lines')
testing_lines = load('testing_lines')

# %% [markdown]
# # Classification

# %%
```create_grams``` : gets the grams given a sentence
```counts``` : gets the count of the

# %%
def create_grams(sent, i, N):
    grams = tuple()
    for j in range(i-N+1, i+1):
        try:
            if j < 0:
                grams += (' ', )
            else:
                grams += (sent[j].split('   ')[0], )
        except:
            grams += (' ', )
    return grams

def counts(data, N):
    counter = {}
    for sentences in data:
        for iter, token_group in enumerate(sentences):
            tokens = token_group.split('   ') # 3 spaces to get the various coloumns
            if len(tokens) == 3: # All the three elements exist
                if tokens[2] in counter:
                    counter[tokens[2]].update([create_grams(sentences, iter, N)])
                else:
                    counter[tokens[2]] = collections.Counter([create_grams(sentences, iter, N)])
    return counter

def make_counts():
    counts_dict = load('count_dict')
    if not counts_dict:
        counts_dict = {}
        for iter in range(1, 4):
            counts_dict[iter] = counts(training_lines, iter)
        save(counts_dict, 'count_dict')
    print("counts made")
    return counts_dict
# counts has the counter of all the error classes with it's various words in it
count = make_counts()
# Out:
# counts made

# %%
count[2]
# Out:
# {'Nn': Counter({('house', 'effect'): 1,
#           (':', '//www.purdue.edu/uns/x/2007a/070314agrawalbiomass.html'): 1,
#           ('faraway', 'situation'): 1,
#           ('the', 'way'): 1,
#           (',', 'individual'): 10,
#           ('migration', 'issue'): 1,
#           ('that', 'incident'): 1,
#           ('require', 'much'): 1,
#           (',', 'it'): 1,
#           (' ', 'human'): 2,
#           ('design', 'process'): 17,
#           ('hidden', 'problem'): 1,
#           ('real', 'condition'): 1,
#           (' ', 'adult'): 1,
#           ('funded', 'field'): 1,
#           ('that', 'crimes'): 1,
#           ('carbon', 'emission'): 2,
#           ('far', 'distance'): 1,
#           ('education', 'opportunity'): 1,
#           ('the', 'coins'): 1,
#           ('of', 'rbmk'): 1,
#           ('as', 'human'): 6,
#           ('facing', 'illness'): 1,
#           ('and', 'inconvenience'): 1,
#           ('in', 'the'): 6,
#           ('her', 'relative'): 1,
#           ('ongoing', 'researches'): 2,
#           ('medical', 'cure'): 1,
#           ('these', 'individual'): 1,
#           ('such', 'condition'): 1,
#           ('family', 'member'): 6,
#           ('energy', 'plant'): 2,
#           ('low', 'income'): 1,
#           ('safety', 'mechanism'): 2,
#           ('of', 'efforts'): 2,
#           ('kidnapping', 'rates'): 1,
#           ('in', 'particulars'): 1,
#           (')', 'reactors'): 1,
#           ('main', 'tasks'): 1,
#           ('financial', 'supports'): 2,
#           ('their', 'commitment'): 1,
#           ('multiple', 'layer'): 1,
#           ('this', 'problem'): 1,
#           ('energy', 'demand'): 3,
#           ('and', 'terrorist'): 1,
#           ('with', 'regards'): 3,
#           ('physical', 'body'): 1,
#           ('some', 'breakthrough'): 1,
#           ('safety', 'issue'): 2,
#           ('a', 'crucial'): 1,
#           ('old', 'one'): 1,
#           ('one', 'is'): 1,
#           ('memory', 'space'): 1,
#           ('marketing', 'department'): 1,
#           ('pay', 'much'): 1,
#           ('their', 'citizen'): 2,
#           ('the', 'act'): 1,
#           ('an', 'engineer'): 2,
#           ('engineer', ','): 1,
#           ('and', 'man'): 1,
#           ('erroneous', 'part'): 1,
#           ('the', 'government'): 4,
#           ('of', 'resource'): 3,
#           ('new', 'source'): 1,
#           ('source', '--'): 1,
#           ('--', '--'): 1,
#           ('--', 'wave'): 1,
#           ('outer', 'resource'): 1,
#           ('to', 'company'): 2,
#           ('of', 'a'): 4,
#           ('a', 'child'): 1,
#           (' ', 'researches'): 4,
#           ('building', 'eyes'): 2,
#           ('treatment', 'center'): 2,
#           ('more', 'emission'): 1,
#           ('house', 'gas'): 2,
#           ('longer', 'period'): 1,
#           ('period', '.'): 1,
#           ('teaching', 'staffs'): 1,
#           ('chronic', 'disease'): 1,
#           ('more', 'subsidy'): 1,
#           ('during', 'the'): 1,
#           ('hdb', 'flat'): 2,
#           ('more', 'moneys'): 1,
#           ('rfid', 'implant'): 3,
#           ('store', 'patient'): 1,
#           ('patient', "'s"): 4,
#           ('3g', 'technique'): 1,
#           ('dramatic', 'change'): 1,
#           ('design', 'solution'): 1,
#           ('important', 'technologies'): 1,
#           ("'s", 'action'): 2,
#           ('safety', 'measure'): 3,
#           ('this', 'technology'): 1,
#           ('some', 'researches'): 2,
#           ('these', 'researches'): 2,
#           ('healthcare', 'cost'): 5,
#           ('serious', 'illness'): 2,
#           ('power', 'reactor'): 2,
#           ('to', 'the'): 7,
#           ('the', 'old'): 1,
#           ('old', 'person'): 1,
#           ('active', 'mind'): 1,
#           ('skilled', 'engineer'): 1,
#           ('who', 'are'): 1,
#           ('new', 'paradigm'): 1,
#           ('new', 'approach'): 1,
#           ('reduce', 'delay'): 1,
#           ('housing', 'estate'): 3,
#           ('causing', 'complication'): 1,
#           ('bad', 'effect'): 1,
#           ('birth', 'rate'): 2,
#           ('uncertain', 'danger'): 1,
#           ('surveillance', 'camera'): 1,
#           ('fossil', 'fuels'): 11,
#           ('and', 'moral'): 1,
#           ('likes', 'governments'): 1,
#           ('contact', 'number'): 1,
#           (';', 'airplane'): 1,
#           ('wheel', 'chair'): 1,
#           ('no', 'child'): 1,
#           ('are', 'numbers'): 1,
#           (',', 'scwr'): 1,
#           ('case', 'accident'): 1,
#           ('are', 'pensions'): 1,
#           ('iv', 'reactor'): 5,
#           (' ', 'program'): 1,
#           ('the', 'design'): 3,
#           ('design', ','): 1,
#           (',', 'operating'): 1,
#           ('operating', ','): 1,
#           (',', 'and'): 1,
#           ('and', 'regulatory'): 1,
#           ('regulatory', 'crew'): 1,
#           ('deteriorating', ','): 1,
#           ('fitness', 'corner'): 2,
#           ('their', 'live'): 1,
#           ('101', 'death'): 2,
#           ('healthcare', 'fee'): 1,
#           ('health', 'expenditure'): 1,
#           ('design', 'team'): 1,
#           ('and', 'the'): 1,
#           ('health', 'subsidy'): 3,
#           ('for', 'examples'): 1,
#           ('of', 'lift'): 3,
#           ('much', 'efforts'): 1,
#           ('risk', 'hazard'): 1,
#           ('promising', 'model'): 1,
#           ('current', 'researched'): 1,
#           ('the', 'present'): 1,
#           ("'s", 'engineer'): 2,
#           ('appropriate', 'equipments'): 1,
#           ('the', 'benefits'): 2,
#           ('economical', 'factor'): 1,
#           ('will', 'be'): 1,
#           ('the', 'aged'): 3,
#           (',', 'the'): 11,
#           ('the', 'community'): 1,
#           ('community', 'hospital'): 3,
#           ('by', 'human'): 4,
#           ('shared', 'dream'): 1,
#           ('certain', 'image'): 1,
#           ('tracking', 'human'): 1,
#           ('for', 'laptop'): 1,
#           ('research', 'method'): 1,
#           ('certain', 'state'): 1,
#           ('the', 'pension'): 2,
#           ('their', 'sibling'): 1,
#           ('consumption', 'level'): 1,
#           ('by', 'government'): 2,
#           ('country', "'s"): 1,
#           ('these', 'offer'): 1,
#           ('in', 'prices'): 1,
#           ('system', 'to'): 1,
#           ('reserve', 'fund'): 1,
#           ('medicine', 'and'): 1,
#           ('trade', 'relationship'): 1,
#           ('engineering', 'problem'): 1,
#           ('and', 'phonebook'): 1,
#           ('phonebook', 'memory'): 1,
#           ('memory', '.'): 1,
#           ('and', 'infrastructures'): 1,
#           ('their', 'family'): 4,
#           ('even', '-'): 1,
#           ('are', 'inevitable'): 2,
#           ('inevitable', '.'): 1,
#           ('insufficient', 'lands'): 1,
#           ('the', 'process'): 1,
#           (' ', 'engineer'): 2,
#           ('heavy', 'subsidy'): 1,
#           ('heavy', 'taxes'): 1,
#           ('taxes', 'levy'): 1,
#           ('levy', 'on'): 1,
#           ('in', 'school'): 2,
#           ('the', 'other'): 2,
#           ('environmental', 'impacts'): 1,
#           ('steps-free', 'entrance'): 1,
#           ('and', 'exit'): 1,
#           ('screening', 'program'): 1,
#           ('for', 'the'): 8,
#           ('the', 'senior'): 1,
#           ('senior', 'citizen'): 10,
#           ('low', 'amount'): 1,
#           ('on', 'infrastructures'): 1,
#           ('accident', 'shows'): 1,
#           ('power', 'plant'): 20,
#           ('nuclear', 'source'): 1,
#           ('political', 'decision'): 1,
#           ('electric', 'bicycle'): 1,
#           ('the', 'events'): 1,
#           ('business', 'opporunity'): 1,
#           ('on', 'the'): 2,
#           ('to', 'complete'): 1,
#           ('younger', 'generation'): 3,
#           ('public', 'fund'): 1,
#           ('large', 'scales'): 1,
#           ('public', 'transports'): 2,
#           ('nuclear', 'wastes'): 1,
#           ('of', 'problem'): 1,
#           ('medisave', 'required'): 1,
#           ('preventing', 'accident'): 1,
#           ('government', 'can'): 1,
#           (',', '2005'): 1,
#           ('improved', 'version'): 1,
#           ('human', 'kinds'): 1,
#           ('sustaining', 'lives'): 1,
#           ('lives', ','): 1,
#           (',', 'causing'): 1,
#           ('and', 'incentive'): 2,
#           ('alternatives', 'road'): 1,
#           (',', 'feature'): 1,
#           ('more', 'researches'): 2,
#           ('researches', '.'): 1,
#           ('from', 'many'): 1,
#           ('solution', 'for'): 1,
#           ('the', 'limitation'): 2,
#           ('the', 'problem'): 2,
#           ('about', 'the'): 3,
#           ('the', 'earthquake'): 1,
#           ('several', 'test'): 1,
#           ('through', 'researches'): 2,
#           ('4', 'international'): 1,
#           ('research', 'and'): 2,
#           ('current', 'circumstance'): 2,
#           ('the', 'researches'): 2,
#           ('of', 'household'): 1,
#           (',', '-'): 2,
#           ('identify', '-'): 1,
#           ('of', '-'): 2,
#           ('help', 'the'): 1,
#           ('free', 'building'): 1,
#           ('the', 'case'): 1,
#           ('also', 'proofs'): 1,
#           ('people', 'to'): 1,
#           (',', 'i'): 1,
#           ('power', 'system'): 1,
#           ('tv', 'artist'): 1,
#           ('from', 'scientist'): 1,
#           ('the', 'excuse'): 1,
#           (' ', 'company'): 2,
#           ('the', 'supports'): 2,
#           ('and', 'helps'): 1,
#           ('rfid', 'tag'): 2,
#           ('sewer', 'system'): 1,
#           ('water', 'source'): 1,
#           ('own', 'saving'): 1,
#           ('enough', 'budgets'): 1,
#           ('engine', 'was'): 1,
#           ('if', 'fundings'): 1,
#           ('for', 'researches'): 1,
#           ('college', 'graduates'): 1,
#           ('security', 'issue'): 1,
#           ('and', 'jewelleries'): 1,
#           ('ensure', 'national'): 1,
#           ('virtual', 'interface'): 1,
#           ('a', 'disease'): 1,
#           ('containment', 'without'): 1,
#           ('the', '3m'): 3,
#           ('psychological', 'problem'): 1,
#           ('engineering', 'incidence'): 1,
#           (' ', 'government'): 8,
#           ('technical', 'university'): 1,
#           ('outer', 'facade'): 1,
#           ('the', 'roof'): 1,
#           ('rescue', 'operation'): 1,
#           ('or', 'investigation'): 1,
#           ('working', 'singaporeans'): 1,
#           ('of', 'electricity'): 1,
#           ('their', 'house'): 3,
#           ('a', 'country'): 2,
#           (' ', 'discriminations'): 1,
#           ('necessary', 'treatments'): 1,
#           ('first', 'laptops'): 1,
#           ('mental', 'problem'): 1,
#           ('manufacturing', 'cost'): 1,
#           ('cost', '.'): 1,
#           ('bad', 'decision'): 1,
#           ('communication', 'devices'): 1,
#           ('certain', 'objection'): 1,
#           ('their', 'lifestyle'): 1,
#           ('nuclear', 'reactor'): 17,
#           ('since', 'accident'): 1,
#           ('huge', 'disaster'): 1,
#           ('since', 'man'): 1,
#           ('forced', 'saving'): 1,
#           ('annuity', 'scheme'): 1,
#           ('individual', 'is'): 1,
#           ('legal', 'protections'): 2,
#           ('design', 'changes'): 1,
#           ('financial', 'stresses'): 2,
#           ('from', 'lesser'): 1,
#           ('to', 'a'): 1,
#           ('entirely', 'valid'): 1,
#           ('be', 'spent'): 1,
#           ('out', 'in'): 1,
#           ('of', 'plant'): 1,
#           ('and', 'chemical'): 2,
#           (',', 'myspace'): 1,
#           ('many', 'researches'): 2,
#           ('of', 'conveniences'): 1,
#           ('of', 'coals'): 1,
#           ('and', 'oils'): 1,
#           ('financial', 'inputs'): 2,
#           ('the', 'physician'): 5,
#           ('the', 'genetics'): 1,
#           ('considers', 'solution'): 1,
#           ('physician', 'and'): 1,
#           ('and', 'expert'): 1,
#           (',', 'there'): 2,
#           ('first', 'advantages'): 1,
#           (' ', 'opponent'): 3,
#           ('of', 'fund'): 5,
#           ('these', 'cost'): 1,
#           ('such', 'kind'): 2,
#           ('development', 'in'): 2,
#           ('encourages', 'singaporean'): 1,
#           ('caused', 'the'): 1,
#           ('the', 'yield'): 1,
#           ('wellness', 'centre'): 1,
#           ('large', 'amount'): 5,
#           ('hospital', 'and'): 1,
#           ('and', 'nursing'): 1,
#           ('nursing', 'home'): 3,
#           (',', 'losses'): 1,
#           ('future', 'generation'): 4,
#           ('states', 'an'): 1,
#           (',', 'vehicle'): 1,
#           ('with', 'multi-solution'): 1,
#           ('200', 'case'): 1,
#           ('bring', 'benefit'): 3,
#           ('hospital', 'stay'): 1,
#           ('the', 'tax'): 1,
#           ('care', 'cost'): 1,
#           ('of', 'train'): 2,
#           ('of', 'airplane'): 1,
#           ('safety', 'aspect'): 1,
#           ('life', 'form'): 1,
#           ('psychology', 'will'): 1,
#           ('money', 'in'): 1,
#           ('upcoming', 'generation'): 1,
#           ('government', 'efforts'): 1,
#           ('we', 'human'): 2,
#           (' ', 'this'): 1,
#           ('this', 'incentive'): 1,
#           ('poorer', 'family'): 1,
#           ('energy', 'problem'): 1,
#           ('daily', 'life'): 5,
#           ('manufacturing', 'factory'): 1,
#           ('the', 'consumer'): 1,
#           ('h1n1', 'patient'): 1,
#           ('should', 'prepare'): 1,
#           ('solar', 'panel'): 2,
#           ('because', 'parent'): 1,
#           ('there', 'can'): 1,
#           ('main', 'source'): 1,
#           ('creative', 'innovation'): 1,
#           ('the', 'surrounding'): 1,
#           ('living', 'condition'): 3,
#           ('deeper', 'researches'): 1,
#           ('the', 'rights'): 8,
#           ('the', 'building'): 3,
#           ('building', 'will'): 1,
#           ('after', 'several'): 1,
#           ('several', 'researches'): 1,
#           ('saving', 'the'): 1,
#           ('their', 'lives'): 1,
#           ('related', 'issue'): 1,
#           ('possible', 'accident'): 2,
#           ('the', 'respondent'): 1,
#           ('best', 'target'): 1,
#           ('huge', 'sum'): 1,
#           ('their', 'salary'): 3,
#           ('innovative', 'design'): 1,
#           ('mega', 'watt'): 1,
#           ('giga', 'watt'): 1,
#           ('reduce', 'the'): 1,
#           ('the', 'expensive'): 1,
#           ('expensive', 'medical'): 1,
#           ('medical', 'fee'): 1,
#           (',', 'psychologist'): 1,
#           ('to', 'administer'): 1,
#           ('civilian', 'uses'): 1,
#           (',', 'fund'): 1,
#           ('their', 'job'): 1,
#           ('salt', 'reactors'): 1,
#           ('single', 'people'): 1,
#           ('people', 'and'): 1,
#           ('and', 'organizations'): 1,
#           ('public', 'discussion'): 1,
#           ('exchange', 'program'): 1,
#           ('older', 'estate'): 2,
#           ('the', 'estate'): 1,
#           ('to', 'consider'): 1,
#           ('benefit', 'some'): 1,
#           ('some', 'industries'): 1,
#           ('do', 'researches'): 2,
#           ('car', 'engine'): 1,
#           ("'", 'deficiencies'): 1,
#           (',', 'schedule'): 1,
#           ('schedule', ','): 1,
#           (',', 'location'): 1,
#           ('of', 'operation'): 1,
#           ('provide', 'sponsor'): 1,
#           ('pharmaceutical', 'medicine'): 1,
#           ('testing', 'result'): 2,
#           ('insufficient', 'fund'): 2,
#           ('the', 'function'): 3,
#           ('nuclear', 'plant'): 9,
#           ('environmental', 'problem'): 3,
#           ('the', 'cars'): 1,
#           ('can', 'spend'): 1,
#           ('genetic', 'test'): 2,
#           ('significant', 'contribution'): 3,
#           ('premised', 'human'): 1,
#           ('of', 'fuels'): 2,
#           ('this', 'test'): 1,
#           ('sufficient', 'fund'): 1,
#           ('the', 'test'): 1,
#           ('social', 'problem'): 3,
#           ('selecting', 'solution'): 1,
#           ('allow', 'government'): 1,
#           ("'s", 'product'): 1,
#           ('other', 'country'): 4,
#           ('development', 'area'): 1,
#           ('government', 'pension'): 1,
#           ('japanese', 'employee'): 1,
#           ('to', 'other'): 2,
#           ('aid', 'researcher'): 1,
#           ('two', 'aspect'): 1,
#           ('every', 'children'): 1,
#           ('aging', 'effect'): 1,
#           ('treatment', 'for'): 1,
#           ('for', 'any'): 1,
#           ('that', 'human'): 3,
#           ('the', 'airplanes'): 1,
#           ('customer', 'requirement'): 1,
#           ('human', 'beings'): 1,
#           ('beings', "'"): 1,
#           ('made', 'adjustment'): 1,
#           ('home', 'use'): 1,
#           ('``', '-'): 1,
#           ('another', 'challenges'): 1,
#           ('the', 'resource'): 2,
#           (' ', 'survey'): 1,
#           ('overwhelming', 'effect'): 1,
#           ('engineering', 'design'): 1,
#           ('to', 'human'): 3,
#           ('issues', 'that'): 1,
#           ('medical', 'advices'): 1,
#           ('their', 'parent'): 3,
#           ('the', 'need'): 7,
#           ('every', 'people'): 1,
#           ('vulnerable', 'group'): 3,
#           ('that', 'they'): 1,
#           ('interference', 'in'): 1,
#           ('and', 'control'): 1,
#           ('natural', 'resources'): 1,
#           ('living', 'expense'): 1,
#           ('monitoring', 'equipments'): 1,
#           ('significant', 'success'): 1,
#           ('generation', 'of'): 1,
#           ('there', 'has'): 1,
#           ('aging', 'population'): 6,
#           ('other', 'part'): 1,
#           ('imminst.org', ')'): 1,
#           ('many', 'hospital'): 1,
#           ('and', 'difference'): 2,
#           ('without', 'shelters'): 1,
#           ('friendly', 'escalator'): 1,
#           ('energy', 'consumptions'): 1,
#           ('of', 'patient'): 3,
#           ('of', 'supports'): 2,
#           ('direct', 'cause'): 1,
#           ('important', 'aspect'): 1,
#           ('their', 'student'): 1,
#           ('the', 'god'): 1,
#           ('god', 'lives'): 1,
#           ('metal', 'conduit'): 1,
#           ('plastic', 'conduit'): 3,
#           ('conduit', 'has'): 1,
#           ('medical', 'leaves'): 2,
#           ('consult', 'treatments'): 1,
#           ('preliminary', 'testing'): 1,
#           ('aside', 'portion'): 1,
#           ('us', 'solution'): 1,
#           ('sufficient', 'assistances'): 1,
#           ('human', "'s"): 7,
#           ('manipulate', 'hormone'): 1,
#           ('hormone', 'level'): 1,
#           ('metabolism', 'level'): 1,
#           ('for', 'supports'): 1,
#           ('new', 'type'): 1,
#           ('of', 'laptop'): 1,
#           ('the', 'concern'): 1,
#           ('undesirable', 'productions'): 1,
#           ('such', 'as'): 2,
#           ('fossil', 'fuel'): 7,
#           ('energy', 'source'): 8,
#           ('source', '.'): 1,
#           ('his', 'skins'): 1,
#           ('an', 'absolute'): 1,
#           ('the', 'wheelchair'): 1,
#           ('because', 'accidents'): 1,
#           ('age', 'group'): 2,
#           ('young', 'generation'): 1,
#           ('the', 'elder'): 1,
#           ('elder', '.'): 1,
#           ('traditional', 'resource'): 2,
#           ('preventing', 'the'): 1,
#           ('the', 'accident'): 5,
#           ('consuming', 'energies'): 1,
#           (',', 'government'): 2,
#           ('and', 'company'): 2,
#           ('heavy', 'metal'): 1,
#           ('the', 'values'): 1,
#           ('all', 'works'): 1,
#           ('alternative', 'source'): 1,
#           ('healthcare', 'sectors'): 1,
#           ('efficient', 'resource'): 1,
#           ('with', 'experiences'): 1,
#           ('take', 'risk'): 1,
#           ('more', 'considerations'): 1,
#           ('and', 'coals'): 1,
#           ('changing', 'demographic'): 1,
#           ('occasional', 'visit'): 1,
#           (',', 'many'): 1,
#           ('few', 'accident'): 1,
#           ('every', 'aspects'): 1,
#           ('population', 'issue'): 1,
#           ('sea', 'wave'): 1,
#           ('receive', 'little'): 1,
#           ('little', 'salary'): 1,
#           ('through', 'research'): 1,
#           ('the', 'politic'): 1,
#           ('some', 'place'): 1,
#           ('energy', 'product'): 2,
#           ('energy', 'converter'): 3,
#           ('for', 'each'): 1,
#           ('each', 'citizen'): 1,
#           ('mobile', 'phone'): 2,
#           ('(', 'vhtr'): 1,
#           ('the', 'improvement'): 5,
#           ('automobile', 'researches'): 1,
#           ('car', 'companies'): 1,
#           ('that', 'government'): 2,
#           ('vast', 'amount'): 2,
#           ('his', 'families'): 3,
#           ('special', 'lens'): 1,
#           ('special', 'hearing-aid'): 1,
#           ('new', 'employee'): 1,
#           ('have', 'difficulties'): 1,
#           ('identification', 'purpose'): 1,
#           ('military', 'uses'): 1,
#           ('and', 'fund'): 1,
#           ('other', 'hands'): 1,
#           ('high', 'temperature'): 10,
#           (']', 'dose'): 1,
#           ('not', 'solve'): 2,
#           ('engineering', 'accident'): 2,
#           ('emergency', 'situation'): 2,
#           ('modern', 'technology'): 1,
#           ('lead', 'user'): 5,
#           ('reactor', 'has'): 1,
#           ('other', '-'): 1,
#           ('moral', 'value'): 1,
#           ('its', 'citizen'): 3,
#           ('installed', 'lift'): 1,
#           ('a', 'large'): 1,
#           ('the', 'responsibility'): 1,
#           ('construction', 'costs'): 1,
#           ('suitable', 'method'): 1,
#           ('to', 'make'): 1,
#           ('their', 'advice'): 1,
#           ('of', 'accident'): 3,
#           ('untreatable', 'disease'): 1,
#           ('in', 'preventing'): 1,
#           (' ', 'all'): 1,
#           ('all', 'these'): 1,
#           ('new', 'kind'): 1,
#           ('their', 'skill'): 1,
#           ('with', 'e-bike'): 1,
#           ('of', 'standards'): 1,
#           ('received', 'treatment'): 1,
#           ('chronic', 'illness'): 1,
#           ('for', 'innovations'): 3,
#           ('financial', 'difficulty'): 1,
#           ('employability', 'problem'): 1,
#           ('little', 'that'): 1,
#           ('satisfy', 'human'): 1,
#           ('spied', '-'): 1,
#           ('oil', 'industry'): 1,
#           ('so', 'much'): 1,
#           ('much', 'policy'): 1,
#           (' ', 'argument'): 1,
#           ('hospital', 'stays'): 1,
#           ('all', 'time'): 1,
#           ('new', 'explosive'): 2,
#           ('got', 'disease'): 1,
#           ('wasting', 'taxpayer'): 1,
#           ('taxpayer', "'s"): 1,
#           ('further', 'investigation'): 1,
#           ('liability', 'test'): 1,
#           ('them', '.'): 1,
#           ('tie', 'rod'): 1,
#           ('social', 'obligation'): 1,
#           ('business', 'opportunity'): 1,
#           ('technological', 'advancement'): 1,
#           ('for', 'human'): 2,
#           ('powered', 'car'): 1,
#           ('not', 'yet'): 1,
#           ('yet', 'known'): 1,
#           ('as', 'a'): 2,
#           ('a', 'weapon'): 1,
#           ('for', 'singaporean'): 3,
#           ('for', 'student'): 1,
#           ('other', 'resource'): 1,
#           ('community', 'services'): 1,
#           ('allows', 'engineer'): 1,
#           ('more', 'fund'): 1,
#           ('and', 'implementations'): 1,
#           ('and', 'weakness'): 1,
#           ('previous', 'design'): 1,
#           ('steam', 'cycle'): 1,
#           ('send', 'soldier'): 1,
#           ('long', 'queue'): 1,
#           ('always', 'make'): 1,
#           ('any', 'forms'): 1,
#           ('c.', 'asian'): 1,
#           ('from', 'illness'): 1,
#           ('people', '-'): 1,
#           ('hospitalization', 'fee'): 1,
#           ('affect', 'patient'): 1,
#           ('therefore', 'individual'): 1,
#           ('any', 'situations'): 1,
#           ('elderly', 'resident'): 1,
#           ('skilled', 'worker'): 1,
#           ('elderly-friendly', 'infrastructure'): 1,
#           ('the', 'expenditures'): 1,
#           ('medical', 'bill'): 3,
#           ('current', 'life'): 1,
#           ('cycle', 'system'): 1,
#           ('which', 'carries'): 1,
#           ('welfare', 'expenditures'): 1,
#           ('electric', 'motorbike'): 1,
#           ('of', 'aspect'): 1,
#           ('young', 'adult'): 1,
#           ('prevent', 'accident'): 1,
#           ('of', 'resistances'): 1,
#           ('and', 'environment'): 1,
#           ('stressful', 'life'): 1,
#           ('population', 'is'): 1,
#           ('in', 'term'): 4,
#           ('as', 'female'): 1,
#           ('military', 'interest'): 1,
#           ('keyhole', 'technique'): 1,
#           ('untouchable', 'tissue'): 1,
#           ('in', 'temperatures'): 1,
#           ('heart', 'muscle'): 1,
#           ('rfid', 'chips'): 1,
#           ('about', 'many'): 1,
#           ('make', 'improvement'): 2,
#           ('surveillance', 'devise'): 1,
#           ('different', 'way'): 2,
#           ('engineers', 'apply'): 1,
#           ('apply', 'their'): 1,
#           ('have', 'rights'): 1,
#           ('the', 'technical'): 1,
#           ('deterring', 'crimes'): 1,
#           ('effectiveness', 'of'): 1,
#           ('their', 'stay'): 1,
#           ('the', 'hospital'): 1,
#           ('check', 'up'): 1,
#           ('the', 'point'): 1,
#           ('health', 'condition'): 1,
#           ('in', 'hospital'): 3,
#           ('subsides', 'rate'): 1,
#           ('their', 'limitation'): 2,
#           ('twenty-five', 'percents'): 1,
#           ('eighteen', 'percents'): 1,
#           ('for', 'advices'): 1,
#           ('technological', 'invents'): 1,
#           ('such', 'problem'): 1,
#           (' ', 'these'): 2,
#           ('these', 'technologies'): 1,
#           ('popular', 'beliefs'): 1,
#           ('the', 'statistic'): 4,
#           ('other', 'alternative'): 1,
#           ('individuals', ','): 1,
#           ('process', 'of'): 1,
#           ('new', 'purpose'): 1,
#           ('no', 'worries'): 1,
#           ('have', 'to'): 2,
#           ('room', 'operator'): 1,
#           ('the', 'automobiles'): 1,
#           ('of', 'terrorist'): 1,
#           ('young', 'ages'): 1,
#           ('it', 'is'): 3,
#           ('of', 'reactor'): 4,
#           ('reactors', 'plant'): 1,
#           ('their', 'preparedness'): 1,
#           ('abnormal', 'gene'): 2,
#           ('genetic', 'disorder'): 1,
#           ('their', 'life'): 11,
#           ('their', 'relative'): 2,
#           ('from', '-'): 2,
#           ('wages', '-'): 1,
#           ('traditional', 'mindset'): 1,
#           ('the', 'number'): 1,
#           ("'s", 'contexts'): 1,
#           ('surveillance', 'system'): 1,
#           ('administrative', 'purpose'): 1,
#           (' ', 'the'): 4,
#           ('next', 'generations'): 1,
#           ('if', 'terrorist'): 1,
#           ('the', 'governments'): 1,
#           ('their', 'desktop'): 1,
#           ('the', 'terrorist'): 3,
#           ('terrorist', "'s"): 1,
#           ("'s", 'plan'): 1,
#           ('their', 'result'): 1,
#           ('cancer', 'death'): 1,
#           ('if', 'expenditures'): 1,
#           ('economically', 'active'): 1,
#           ('active', 'persons'): 1,
#           ('thus', 'individual'): 2,
#           ('medical', 'centre'): 2,
#           ('disclose', 'the'): 1,
#           ('the', 'result'): 3,
#           ('new', 'lfr'): 1,
#           ('the', 'environmental'): 1,
#           ('environmental', 'factor'): 1,
#           ('to', 'accommodate'): 1,
#           ('skunk', 'works'): 1,
#           ('brings', 'benefit'): 1,
#           ('life', 'time'): 1,
#           ('friendly', 'design'): 2,
#           ('making', 'decision'): 1,
#           ('everyday', 'life'): 1,
#           ('each', 'country'): 1,
#           ('different', 'level'): 1,
#           ('their', 'society'): 1,
#           ('social', 'policy'): 2,
#           ('the', 'discoveries'): 1,
#           ('most', 'country'): 2,
#           ('electromagnetic', 'wave'): 2,
#           ('different', 'material'): 1,
#           ('strategy', 'really'): 1,
#           ('by', 'the'): 1,
#           ('because', 'the'): 1,
#           ('in', '-'): 1,
#           ('speech', ','): 1,
#           ('positive', 'impacts'): 2,
#           ('allows', 'user'): 1,
#           ('in', 'government'): 1,
#           ('practical', 'measure'): 1,
#           ('genetic', 'researches'): 1,
#           ('new', 'form'): 1,
#           ('human', 'being'): 6,
#           ('common', 'fields'): 1,
#           ('the', 'examples'): 1,
#           ('working', 'place'): 1,
#           ('working', 'experiences'): 1,
#           ('the', 'experiences'): 1,
#           ('normal', 'circumstance'): 1,
#           ("'", 'need'): 2,
#           ('train', 'platform'): 1,
#           ('first', 'differences'): 1,
#           ('between', 'financial'): 1,
#           (',', 'resource'): 1,
#           ('medical', 'cost'): 2,
#           ('is', 'one'): 1,
#           ('one', 'of'): 2,
#           ('some', 'parts'): 1,
#           ('17', 'percents'): 1,
#           ('the', 'user'): 2,
#           ('invest', 'billion'): 1,
#           ('new', 'discovery'): 1,
#           ('in', 'contrast'): 1,
#           ('their', 'pressures'): 1,
#           ('process', 'task'): 1,
#           ('nuclear', 'weapon'): 10,
#           ('certain', 'segment'): 1,
#           ('and', 'efforts'): 3,
#           ('by', 'robot'): 1,
#           ('other', 'kind'): 2,
#           ('and', 'building'): 1,
#           ('such', 'measure'): 1,
#           ('living', 'problem'): 1,
#           ('to', 'elders'): 1,
#           ('that', 'scientist'): 1,
#           ('while', 'government'): 1,
#           ('the', 'numbers'): 3,
#           ('in', 'toilet'): 1,
#           ('tap', 'lever'): 1,
#           ('not', 'improve'): 1,
#           ('improve', 'the'): 1,
#           ('freedom', 'does'): 1,
#           ('a', 'global'): 1,
#           ('cause', 'individual'): 1,
#           ('it', 'user'): 1,
#           ('high', 'rate'): 1,
#           ('the', 'reason'): 2,
#           ('and', 'developments'): 2,
#           ('include', 'maintenances'): 1,
#           ('hospitals', 'staffs'): 1,
#           ('public', 'opinions'): 1,
#           ('the', 'demands'): 1,
#           ('efficient', 'way'): 1,
#           ('of', 'area'): 1,
#           ('some', 'problem'): 1,
#           ('unnecessary', 'thing'): 1,
#           ('preventive', 'measure'): 1,
#           ('signals', 'from'): 1,
#           ('as', 'coals'): 1,
#           ('of', 'labours'): 1,
#           ('new', 'innovation'): 1,
#           ('first', 'one'): 1,
#           ('proposed', 'bonus'): 1,
#           ('and', 'allowance'): 1,
#           ('valuable', 'contribution'): 1,
#           ('best', 'decision'): 1,
#           ('among', 'singaporean'): 1,
#           ('the', 'citizen'): 2,
#           ('citizen', "'s"): 1,
#           ('related', 'illness'): 1,
#           ('mortality', 'rate'): 1,
#           ('life-threatening', 'condition'): 1,
#           ('its', 'unit'): 1,
#           ('revealing', 'the'): 1,
#           ('test', 'result'): 2,
#           ('of', 'economic'): 1,
#           ('economic', 'condition'): 1,
#           ('``', 'appearance'): 1,
#           ('appearance', 'patent'): 1,
#           ('young', 'worker'): 1,
#           ('late', 'marriage'): 2,
#           ('fiscal', 'cost'): 2,
#           ('dangerous', 'if'): 1,
#           ('of', 'complications'): 1,
#           ('buying', 'machine'): 1,
#           ('while', 'other'): 1,
#           ('potential', 'discriminations'): 1,
#           ('traditional', 'source'): 1,
#           ('of', 'needs'): 1,
#           ('ancient', 'time'): 1,
#           ('massive', 'death'): 1,
#           ('retirement', 'housings'): 2,
#           ('committing', 'suicides'): 2,
#           ('hour', ','): 1,
#           ('own', 'problem'): 1,
#           ('problem', ','): 1,
#           ('government', 'bond'): 1,
#           ("'s", 'body'): 1,
#           ('and', 'mind'): 1,
#           ('cause', 'disaster'): 1,
#           ('gas-and-electric-powered', 'automobile'): 1,
#           ('16', 'percents'): 1,
#           ('making', 'rooms'): 1,
#           ('power', 'surge'): 1,
#           ('radius', '.'): 1,
#           ('conventional', 'process'): 1,
#           ('corrective', 'actions'): 1,
#           ('consist', 'of'): 1,
#           (',', 'spouse'): 1,
#           ('specific', 'device'): 1,
#           ('significant', 'roles'): 1,
#           ('personal', 'experience'): 1,
#           ('of', 'illness'): 2,
#           ('automated', 'gadget'): 1,
#           ('data', 'exchange'): 1,
#           ('of', 'benefits'): 1,
#           ('wind', 'energy'): 1,
#           ('for', 'plane'): 1,
#           ('wages', 'increases'): 1,
#           ('read', 'campaign'): 1,
#           ('main', 'difficulty'): 1,
#           ('of', 'return'): 1,
#           ('and', 'environmentalist'): 1,
#           ('two', 'very'): 1,
#           ('two', 'finger'): 1,
#           ('the', 'difference'): 1,
#           ('square', 'kilometer'): 1,
#           ('many', 'others'): 1,
#           ('others', 'technology'): 1,
#           ('working', 'condition'): 1,
#           ('developing', 'infrastructures'): 2,
#           ('infrastructures', ','): 1,
#           ('economic', 'growth'): 1,
#           ('valuable', 'design'): 1,
#           ('well', 'beings'): 2,
#           ('traditional', 'moral'): 1,
#           ('friendly', 'decision'): 1,
#           ('such', '-'): 1,
#           ('under', 'test'): 1,
#           ('temporary', 'accommodations'): 1,
#           ('certain', 'group'): 1,
#           ('rising', 'affluences'): 1,
#           ('of', 'citizen'): 2,
#           ('other', 'form'): 1,
#           ('they', 'manufacture'): 1,
#           ('manufacture', '.'): 1,
#           ('decoded', 'product'): 1,
#           ('of', 'death'): 2,
#           ('surveillance', 'technology'): 3,
#           ('is', 'why'): 1,
#           ('their', 'roof'): 1,
#           ('energy', 'panel'): 1,
#           ('their', 'impacts'): 1,
#           ('proposes', '-'): 1,
#           ('that', 'the'): 1,
#           ('public', 'policy'): 1,
#           ('that', 'there'): 1,
#           ('the', 'damages'): 3,
#           ('ethical', 'issue'): 1,
#           ('safety', 'regulation'): 1,
#           ('some', 'fund'): 1,
#           ('only', '50'): 1,
#           ('company', 'guideline'): 1,
#           ('doing', 'researches'): 1,
#           ('and', 'forklift'): 1,
#           ('other', 'helps'): 1,
#           ('fertility', 'rate'): 1,
#           ('invaluable', 'resources'): 1,
#           ('any', 'disorders'): 1,
#           (',', 'policy'): 1,
#           ('excellent', 'product'): 1,
#           ('tracking', 'employees'): 1,
#           ('retirement', 'plan'): 1,
#           ('legislated', 'at'): 1,
#           ('especially', 'vhtr'): 1,
#           ('civics', 'lesson'): 1,
#           ('such', 'programme'): 1,
#           ('the', 'innovations'): 1,
#           ('layer', 'which'): 1,
#           ('future', 'demand'): 1,
#           ('to', 'have'): 1,
#           ('thus', 'government'): 1,
#           ('minimum', 'sum'): 1,
#           ('which', 'human'): 1,
#           ('research', 'staffs'): 4,
#           ('few', 'suggestion'): 1,
#           ('up', 'fund'): 1,
#           ('the', 'development'): 2,
#           ('the', 'technological'): 1,
#           ('technological', 'field'): 1,
#           ('size', 'equipments'): 1,
#           ('adequate', 'amount'): 1,
#           ('almost', 'fourth-fifth'): 1,
#           ('its', 'low'): 1,
#           ('low', 'pressure'): 1,
#           ('that', 'action'): 1,
#           ('have', 'potential'): 1,
#           ('fission', 'product'): 1,
#           ('to', 'vehicle'): 1,
#           ('among', 'human'): 1,
#           ('safety', 'precautions'): 1,
#           ('new', 'tool'): 1,
#           ('different', 'area'): 1,
#           ('more', 'virus'): 1,
#           ('with', 'many'): 1,
#           ('tangible', 'use'): 1,
#           ('generous', 'benefit'): 1,
#           ('of', 'excuse'): 1,
#           ('with', 'gymnastic'): 1,
#           ('the', 'policy'): 1,
#           ('see', 'convertor'): 1,
#           ('economist', 'requirement'): 1,
#           ('greater', 'cost'): 1,
#           ('have', 'a'): 2,
#           ('every', 'movements'): 1,
#           ('technical', 'problem'): 2,
#           ('other', 'reactors'): 1,
#           ('m.', '('): 1,
#           ('medical', 'advancement'): 1,
#           ('more', 'supports'): 1,
#           ('the', 'family'): 1,
#           ('magnetic', 'monopole'): 3,
#           ('early', '1990'): 1,
#           ('nuclear', 'spill'): 1,
#           ('spill', ','): 1,
#           ...}),
#  'Cit': Counter({('probability', 'of'): 1,
#           ('of', 'acquiring'): 1,
#           ('acquiring', 'a'): 1,
#           ('a', 'genetic'): 1,
#           ('genetic', 'disorder'): 1,
#           (' ', 'references'): 2,
#           ('need', 'long'): 1,
#           ('long', 'term'): 1,
#           ('term', 'care'): 1,
#           ('care', ','): 1,
#           (',', 'especially'): 1,
#           ('[', 'hyperlink'): 14,
#           ('hyperlink', ':'): 14,
#           (':', 'http'): 13,
#           ('http', ':'): 19,
#           (':',
#            '//www.associatedcontent.com/topic/15557/nuclear_power.html'): 1,
#           ('by', '2050'): 1,
#           ('higher', 'citation'): 1,
#           ('citation', 'cha04'): 2,
#           ('cha04', '\\l'): 2,
#           ('\\l', '1033'): 13,
#           ('(', 'what'): 1,
#           ('what', 'is'): 2,
#           ('is', 'nuclear'): 1,
#           ('nuclear', 'reprocessing'): 1,
#           ('reprocessing', '?'): 1,
#           ('?', ','): 1,
#           (',', '2000'): 2,
#           (' ', 'david'): 1,
#           ('david', 'e.'): 1,
#           ('e.', 'bloom'): 1,
#           ('bloom', ','): 1,
#           (',', 'david'): 2,
#           ('david', 'canning'): 1,
#           ('canning', 'and'): 1,
#           ('and', 'gunther'): 1,
#           ('gunther', 'fink'): 1,
#           ('fink', '('): 1,
#           ('(', 'april'): 1,
#           ('april', '2008'): 1,
#           ('2008', ')'): 5,
#           (' ', '*'): 1,
#           ('*', 'tan'): 1,
#           ('tan', 'jin'): 1,
#           ('jin', 'soon'): 1,
#           ('soon', ','): 1,
#           (',', 'li'): 1,
#           ('li', 'tieyan'): 1,
#           ('tieyan', '.'): 1,
#           ('(', 'gen-iv'): 1,
#           ('gen-iv', ','): 1,
#           (',', '2005'): 2,
#           ('accident', 'citation'): 1,
#           ('citation', 'che091'): 1,
#           ('che091', '\\l'): 1,
#           ('\\l', '2052'): 5,
#           ('and', 'hydrogen'): 1,
#           ('hydrogen', 'fuel'): 1,
#           ('fuel', '.'): 1,
#           ('economic', ','): 1,
#           (',', 'defence'): 1,
#           ('research', 'shows'): 1,
#           ('shows', 'that'): 1,
#           ('that', '``'): 1,
#           ('``', 'of'): 1,
#           ('of', 'people'): 2,
#           ('people', 'aged'): 1,
#           ('aged', '70'): 1,
#           ('70', 'years'): 1,
#           ('(', 'u.s.'): 1,
#           ('u.s.', 'department'): 1,
#           ('department', 'of'): 1,
#           ('of', 'energy'): 1,
#           ('energy', ','): 1,
#           (',', 'n.d.'): 3,
#           ('n.d.', ')'): 3,
#           (')', '.'): 10,
#           ('them', '.'): 2,
#           ('reactors', 'citation'): 1,
#           ('citation', 'sat08'): 2,
#           ('sat08', '\\l'): 2,
#           ('frot', '('): 1,
#           ('(', '2000'): 1,
#           ('2000', ')'): 1,
#           (')', "'s"): 1,
#           (' ', 'devices'): 1,
#           ('devices', 'must'): 1,
#           ('must', 'be'): 2,
#           ('be', 'easy'): 1,
#           ('world', "''"): 2,
#           ("''", 'citation'): 1,
#           ('citation', 'drg09'): 1,
#           ('drg09', '\\l'): 1,
#           ('(', 'stanton.n'): 1,
#           (' ', '('): 8,
#           ('(', 'gif'): 2,
#           ('gif', ','): 1,
#           (',', 'n.d'): 2,
#           ('n.d', '.'): 1,
#           ('.', ')'): 1,
#           ('it', 'is'): 2,
#           ('(', 'bio'): 1,
#           ('bio', 'tec'): 1,
#           ('in', 'conclusion'): 1,
#           ('conclusion', ','): 1,
#           (',', 'the'): 9,
#           ('graying', 'world'): 1,
#           ("''", '('): 3,
#           ('(', 'page'): 1,
#           ('page', '8'): 1,
#           ('8', ','): 1,
#           (',', 'paragraph'): 1,
#           ('(', 'aacc'): 2,
#           ('aacc', ','): 2,
#           (',', '2009'): 16,
#           ('2009', ';'): 2,
#           (';', 'human'): 1,
#           ('human', 'genome'): 1,
#           ('genome', 'management'): 1,
#           ('management', 'information'): 1,
#           ('information', 'system'): 1,
#           ('system', '['): 2,
#           ('[', 'hgmis'): 1,
#           ('hgmis', ']'): 1,
#           (']', ','): 6,
#           (',', '2008'): 7,
#           ('the', '{'): 1,
#           ('{', 'inflammation'): 1,
#           ('inflammation', '}'): 1,
#           ('}', '['): 12,
#           (':', '//www.naturalnews.com/inflammation.html'): 1,
#           ('//www.naturalnews.com/inflammation.html', ']'): 1,
#           ('-', '['): 1,
#           ('[', '1'): 2,
#           ('1', ']'): 2,
#           ("'s", 'disease'): 1,
#           (')', '-'): 8,
#           (')', '7'): 1,
#           ('societal', 'costs'): 1,
#           ('costs', "''"): 1,
#           ('(', 'robert'): 4,
#           ('b.', 'friedland'): 2,
#           ('friedland', 'and'): 2,
#           ('and', 'laura'): 5,
#           ('laura', 'summer'): 2,
#           ('process', 'heat'): 1,
#           ('heat', 'applications'): 1,
#           ('applications', '.'): 1,
#           ('agents', 'and'): 1,
#           ('and', 'greenhouse'): 1,
#           ('greenhouse', 'gases'): 1,
#           ('gases', 'which'): 1,
#           ('gif', 'forum'): 1,
#           ('in', '12846'): 1,
#           (',', 'prudent'): 1,
#           ('prudent', 'and'): 1,
#           ('and', 'appropriate'): 1,
#           ('appropriate', 'usage'): 1,
#           ('possible', 'due'): 1,
#           ('(', 'n.d.'): 1,
#           ('(', 'hankook'): 1,
#           ('hankook', 'ilbo'): 1,
#           ('(', 'http'): 3,
#           (':', '//www.ashg.org'): 1,
#           ('bring', 'the'): 1,
#           ('the', 'utmost'): 1,
#           ('utmost', 'profit'): 1,
#           ('profit', 'to'): 1,
#           ('to', 'the'): 2,
#           ('the', 'country'): 1,
#           ('productivity', 'and'): 1,
#           ('(', 'as'): 2,
#           ('as', 'cited'): 2,
#           ('cited', 'in'): 1,
#           ('in', 'ministry'): 1,
#           ('ministry', 'of'): 2,
#           ('of', 'health'): 1,
#           ('health', ','): 1,
#           (',', 'singapore'): 1,
#           ('%', 'citation'): 1,
#           ('citation', 'gen08'): 1,
#           ('gen08', '\\l'): 1,
#           ('and', 'to'): 1,
#           ('to', 'have'): 1,
#           ('have', 'some'): 1,
#           ('some', 'ideas'): 1,
#           ('ideas', 'of'): 1,
#           ('of', 'what'): 1,
#           (' ', 'citation'): 2,
#           ('(', 'economist'): 1,
#           ('economist', 'intelligence'): 1,
#           ('intelligence', 'unit'): 1,
#           ('unit', ','): 1,
#           (',', '2007'): 2,
#           ('2007', ','): 1,
#           (',', 'para'): 1,
#           ('para', '1'): 1,
#           ('screen', '['): 1,
#           ('[', '7'): 2,
#           ('7', ']'): 2,
#           ('(', 'zolla'): 1,
#           ('zolla', ','): 1,
#           (',', '96'): 1,
#           ('96', ')'): 1,
#           ('in', 'singapore'): 1,
#           ('singapore', '.'): 1,
#           ('mark', 'roberti'): 1,
#           ('roberti', '.'): 1,
#           ('from', 'khandani'): 1,
#           ('11.42', 'million'): 1,
#           ('(', ')'): 1,
#           ('been', 'fired'): 1,
#           ('compiled', 'and'): 1,
#           ('and', 'sold'): 1,
#           ('sold', "''"): 1,
#           ('the', 'economic'): 1,
#           ('economic', 'development'): 1,
#           ('development', 'board'): 1,
#           ('board', 'article'): 1,
#           ('article', '('): 1,
#           ('(', '2009'): 7,
#           ('2009', ')'): 9,
#           (')', 'mentioned'): 1,
#           ('mentioned', 'in'): 2,
#           ('in', '2007'): 1,
#           ('(', '2002'): 1,
#           ('2002', ','): 1,
#           (',', 'p257'): 1,
#           ('2000', ','): 1,
#           (',', '4'): 1,
#           ('technologies', '('): 1,
#           ('(', 'cast'): 1,
#           ('cast', ')'): 1,
#           (')', '('): 1,
#           ('finance', '('): 1,
#           ('as', 'we'): 2,
#           (' ', 'from'): 1,
#           ('from', 'early'): 1,
#           ('early', '1960s'): 1,
#           ('1960s', 'to'): 1,
#           ('to', '1980s'): 1,
#           ('1980s', 'there'): 1,
#           ('there', 'were'): 1,
#           ('were', 'several'): 1,
#           ('several', 'anti-nuclear'): 1,
#           ('anti-nuclear', 'movements'): 1,
#           ('movements', 'in'): 1,
#           ('in', 'united'): 1,
#           ('united', 'sates'): 1,
#           (' ', 'centers'): 1,
#           ('centers', 'for'): 1,
#           ('for', 'disease'): 1,
#           ('disease', 'control'): 1,
#           ('control', 'and'): 1,
#           ('and', 'prevention'): 2,
#           ('prevention', '('): 1,
#           ('(', '2007'): 2,
#           ('2007', ')'): 2,
#           (' ', '``'): 3,
#           ('approach', '}'): 1,
#           (':', 'dict'): 1,
#           ('dict', ':'): 1,
#           (':', '//key.0895dfe8db67f9409db285590d870edd/solution'): 1,
#           ('//key.0895dfe8db67f9409db285590d870edd/solution', '%'): 1,
#           ('%', '20approach'): 1,
#           ('20approach', ']'): 1,
#           (']', 'es'): 1,
#           (',', '-'): 2,
#           ('discovery', ','): 1,
#           (',', '('): 2,
#           ('(', 'case'): 1,
#           ('case', 'western'): 1,
#           ('western', 'reserve'): 1,
#           ('reserve', 'university'): 1,
#           ('university', '['): 1,
#           ('[', 'cwru'): 1,
#           ('cwru', ']'): 1,
#           ('(', 'nei'): 1,
#           ('nei', 'source'): 1,
#           ('source', 'book'): 1,
#           (':', '//www.hangzhou.gov.cn/main/xxbs/t152837.shtml'): 1,
#           ('//www.hangzhou.gov.cn/main/xxbs/t152837.shtml', 'accessed'): 1,
#           ('accessed', 'september'): 1,
#           ('september', '4'): 1,
#           ('4', ','): 1,
#           ('is', 'definitely'): 1,
#           ('definitely', 'a'): 1,
#           ('a', 'costly'): 1,
#           ('costly', 'as'): 1,
#           ('as', 'well'): 1,
#           ('well', 'as'): 1,
#           ('as', 'non-feasible'): 1,
#           ('for', 'peaceful'): 1,
#           ('probably', 'prevent'): 1,
#           ('prevent', 'people'): 1,
#           ('people', 'from'): 1,
#           ('quek', '-'): 2,
#           ('seating', "'"): 1,
#           ("'", 'scheme'): 1,
#           ('scheme', ','): 1,
#           ('robert', 'b.'): 4,
#           ('2008', '('): 1,
#           ('(', '``'): 1,
#           ('``', 'what'): 1,
#           ('is', 'credit'): 1,
#           ('credit', 'card'): 1,
#           ('card', "''"): 1,
#           ("''", ','): 2,
#           ('in', '1955'): 1,
#           ('1955', 'as'): 1,
#           ('as', 'a'): 1,
#           ('a', 'form'): 1,
#           ('form', 'of'): 1,
#           ('of', 'funded'): 1,
#           ('that', '{'): 1,
#           ('{', 'kuwait'): 1,
#           ('kuwait', '}'): 1,
#           (':', '//en.wikipedia.org/wiki/kuwait'): 1,
#           ('//en.wikipedia.org/wiki/kuwait', ']'): 1,
#           (']', "'s"): 1,
#           ("'s", '{'): 1,
#           ('{', 'al'): 1,
#           ('al', 'burqan'): 1,
#           ('burqan', 'oil'): 1,
#           ('oil', 'field'): 1,
#           ('field', '}'): 1,
#           (':', '//en.wikipedia.org/wiki/al_burqan_oil_field'): 1,
#           ('//en.wikipedia.org/wiki/al_burqan_oil_field', ']'): 1,
#           ('(', 'pm'): 1,
#           ('pm', 'lee.h.l'): 1,
#           ('lee.h.l', ':'): 1,
#           ('(', 'cna'): 1,
#           ('(', 'said'): 1,
#           ('said', 'by'): 1,
#           ('by', 'patrick'): 1,
#           ('patrick', '('): 1,
#           ('(', 'p.8'): 1,
#           ('p.8', ')'): 1,
#           (')', ')'): 1,
#           (')', ','): 8,
#           ('(', '2005'): 2,
#           (':', '//www.accessexcellence.org'): 1,
#           ('//www.accessexcellence.org', ')'): 1,
#           ('(', 'salma'): 1,
#           ('salma', 'khalik'): 1,
#           ('khalik', ','): 1,
#           ('the', 'straits'): 3,
#           ('straits', 'times'): 3,
#           ('times', ','): 3,
#           ('(', 'bbc'): 2,
#           ('bbc', 'news,2006'): 1,
#           ('(', 'peter'): 2,
#           ('peter', 'g.'): 2,
#           ('although', ','): 1,
#           ('tan', '-'): 1,
#           ('processes', ','): 1,
#           (' ', 'according'): 2,
#           ('according', 'to'): 3,
#           ('to', 'jobstreet.com'): 1,
#           (' ', 'in'): 3,
#           ('in', '1995'): 1,
#           ('1995', ','): 1,
#           (',', 'both'): 1,
#           ('in', 'most'): 1,
#           ('most', 'cases'): 1,
#           ('cases', ','): 1,
#           ('times', ')'): 1,
#           (')', 'by'): 1,
#           ('by', '2030'): 1,
#           ('and', '-'): 1,
#           ('(', 'ref'): 1,
#           ('ref', ':'): 1,
#           (':', '{'): 1,
#           ('{', 'http'): 3,
#           (':', '//timesofindia.indiatimes.com'): 2,
#           ('//timesofindia.indiatimes.com', '}'): 1,
#           ('//timesofindia.indiatimes.com', ']'): 1,
#           ('shift', '-'): 1,
#           ('is', 'a'): 1,
#           ('a', 'distressing'): 1,
#           ('with', 'the'): 1,
#           ('the', 'introduction'): 1,
#           ('issues', 'pertaining'): 1,
#           (')', '4'): 1,
#           (')', '5'): 1,
#           ('to', 'know'): 1,
#           ('know', 'that'): 2,
#           ('that', 'many'): 1,
#           ('(', 'fcd'): 1,
#           ('(', 'the'): 4,
#           ('frieden', '-'): 1,
#           ('fertility', 'rate1'): 1,
#           ('to', '('): 4,
#           ('(', 'dr.'): 1,
#           ('dr.', 'kevin'): 1,
#           ('kevin', 'zorn'): 2,
#           ('zorn', ','): 1,
#           (',', 'chicago'): 1,
#           ('chicago', '('): 1,
#           ('(', 'reuters'): 1,
#           ('reuters', ')'): 1,
#           (')', 'health'): 1,
#           ('health', 'news'): 1,
#           ('news', ','): 1,
#           ('theories', '-'): 1,
#           ('(', '{'): 5,
#           ('{', 'novak'): 1,
#           ('novak', '}'): 1,
# ...
#           ('that', '-'): 2,
#           ('know', '-'): 1,
#           ('world', ','): 1,
#           ('it', 'provides'): 1,
#           (')', '-'): 3,
#           ('elder', ','): 1,
#           (',', 'meanwhile'): 1,
#           ('child', 'besides'): 1,
#           ('besides', 'the'): 1,
#           ('the', 'cash'): 1,
#           ('cash', 'incentives'): 1,
#           ('who', 'still'): 1,
#           ('still', 'contribute'): 1,
#           ('for', 'possible'): 1,
#           ('run', 'which'): 1,
#           ('which', 'leads'): 1,
#           ('leads', 'to'): 1,
#           ('to', 'the'): 2,
#           ('the', 'economical'): 1,
#           ('economical', 'impact'): 1,
#           ('impact', 'as'): 1,
#           ('also', 'make'): 1,
#           ('make', 'patient'): 1,
#           ('patient', 'less'): 1,
#           ('less', 'painful'): 1,
#           ('results', '-'): 1,
#           ('treatment', 'that'): 1,
#           ('companies', 'that'): 1,
#           ('needs', 'of'): 1,
#           ('of', 'the'): 3,
#           ('the', 'forgetting'): 1,
#           ('society', 'which'): 1,
#           ('62', ','): 1,
#           ('also', '-'): 1,
#           ('2004', '-'): 1,
#           ('and', 'development/policies'): 1,
#           ('more', 'singaporeans'): 1,
#           ('people', '-'): 1,
#           ('government', 'who'): 1,
#           (',', 'so'): 1,
#           ('so', 'that'): 1,
#           ('small', '-'): 1,
#           ('cimo', 'help'): 1,
#           ('stone', 'as'): 1,
#           ('as', 'in'): 1,
#           ('in', 'improving'): 1,
#           ('improving', 'two'): 1,
#           ('two', 'sectors'): 1,
#           ('sectors', 'by'): 1,
#           ('by', 'allocating'): 1,
#           ('allocating', 'the'): 1,
#           ('catastrophe', '-'): 1,
#           (',', 'have'): 1,
#           ('technology', 'helping'): 1,
#           ('accident', 'happened'): 1,
#           ('happened', 'in'): 1,
#           ('in', 'june'): 1,
#           ('june', '1998'): 1,
#           (')', 'where'): 1,
#           ('where', 'the'): 1,
#           ('the', 'government'): 1,
#           ('government', 'is'): 2,
#           ('is', 'recognising'): 1,
#           ('recognising', 'the'): 1,
#           ('the', 'importance'): 1,
#           ('importance', 'of'): 1,
#           ('of', 'planning'): 1,
#           ('planning', 'with'): 1,
#           ('world', 'by'): 1,
#           ('question', '-'): 1,
#           ('entrepreneurs', '-'): 1,
#           ('high', ','): 1,
#           ('changes', 'that'): 1,
#           ('courses', 'and'): 1,
#           ('and', 'their'): 1,
#           ('appropriate', 'and'): 1,
#           ('miraculous', 'breakthrough'): 1,
#           ('communication', '-'): 1,
#           ('aged', 'will'): 1,
#           ('will', 'contribute'): 1,
#           ('contribute', 'for'): 1,
#           (',', 'a'): 1,
#           ('a', 'priority'): 1,
#           ('priority', 'made'): 1,
#           ('made', 'for'): 1,
#           ('for', 'elderly'): 1,
#           ('elderly', "'"): 1,
#           ("'", 'convenience'): 1,
#           ('convenience', 'to'): 1,
#           (',', 'allowing'): 1,
#           (',', 'discouraging'): 1,
#           ('look-a-likes', 'which'): 1,
#           ('coming', '-'): 1,
#           ('process', 'due'): 1,
#           ('due', 'that'): 1,
#           ('fund', '-'): 1,
#           ('radiation', '-'): 1,
#           (',', 'ranging'): 1,
#           (' ', 'designing'): 1,
#           ('dangers', '-'): 1,
#           (',', 'providing'): 1,
#           ('expecting', '-'): 1,
#           ('because', 'with'): 1,
#           ('with', 'the'): 1,
#           ('the', 'increase'): 1,
#           ('increase', 'in'): 1,
#           ('in', 'an'): 1,
#           ('an', 'independent'): 1,
#           ('independent', 'group'): 1,
#           ('group', 'of'): 1,
#           ('of', 'elderly'): 1,
#           ('gases', '-'): 1,
#           ('contributions', 'the'): 1,
#           ('the', 'aged'): 1,
#           ('aged', 'have'): 1,
#           ('have', 'made'): 1,
#           ('statistic', 'where'): 1,
#           ('procedures', 'such'): 1,
#           ('such', 'as'): 2,
#           ('as', 'protecting'): 1,
#           ('clear', 'that'): 1,
#           ('reason', '-'): 1,
#           ('lift', '-'): 1,
#           ('process', '-'): 1,
#           ('leakage', '-'): 1,
#           ('carry', '-'): 1,
#           ('and', 'not'): 1,
#           ('and', 'the'): 1,
#           ('the', 'money'): 1,
#           ('money', 'should'): 1,
#           ('should', 'be'): 1,
#           ('be', 'used'): 1,
#           ('used', 'in'): 1,
#           ('in', 'other'): 1,
#           ('other', 'aspects'): 1,
#           ('aspects', 'of'): 1,
#           ('the', 'society'): 1,
#           ('society', 'such'): 1,
#           ('as', 'education'): 1,
#           ('education', ','): 1,
#           (',', 'economic'): 1,
#           ('economic', 'growth'): 1,
#           ('growth', 'and'): 1,
#           ('and', 'healthcare'): 1,
#           ('healthcare', 'of'): 1,
#           ('the', 'public'): 1,
#           ('not', 'only'): 1,
#           ('only', 'the'): 1,
#           ('problem', ','): 1,
#           ('which', 'is'): 1,
#           ('factor', 'which'): 1,
#           (',', 'creating'): 1,
#           ('which', 'reflects'): 1,
#           ('rapidly', 'that'): 1,
#           ('example', 'technology'): 1,
#           (',', 'whereby'): 1,
#           ('hydrogen', '-'): 1,
#           ('issue', 'which'): 1,
#           ('which', 'every'): 1,
#           ('every', 'government'): 1,
#           (',', 'taking'): 1,
#           ('taking', 'its'): 1,
#           ('its', 'depletion'): 1,
#           ('depletion', 'to'): 1,
#           ('the', 'ozone'): 1,
#           ('ozone', 'layer'): 1,
#           ('layer', 'into'): 1,
#           ('into', 'concern'): 1,
#           ('as', '-'): 1,
#           ('alternatives', '-'): 1,
#           ('critical', 'that'): 1,
#           ('health', 'with'): 1,
#           ('with', 'a'): 1,
#           ('a', 'longer'): 1,
#           ('longer', 'age'): 1,
#           ('neglected', 'and'): 1,
#           ('process', 'where'): 1,
#           ('where', 'it'): 1,
#           ('waves', 'across'): 1,
#           ('across', 'europe'): 1,
#           ('europe', 'which'): 1,
#           ('has', 'killed'): 1,
#           ('killed', 'a'): 1,
#           ('a', 'number'): 1,
#           ('number', 'of'): 1,
#           ('of', 'people'): 1,
#           ('lives', 'and'): 1,
#           ('inflation', '-'): 1,
#           ('conversations', '-'): 1,
#           ('services', '-'): 1,
#           ('fleming', 'where'): 1,
#           ('children', 'to'): 1,
#           ('elderly', 'with'): 1,
#           ('manageable', '-'): 1,
#           (',', 'covering'): 1,
#           ('parents', '-'): 1,
#           ('users', 'by'): 1,
#           ('by', 'only'): 1,
#           ('only', 'meeting'): 1,
#           ('system', '-'): 1,
#           ('the', 'performance'): 1,
#           ('performance', 'increase'): 1,
#           ('it', 'also'): 1,
#           ('also', 'may'): 1,
#           ('may', 'help'): 1,
#           ('more', '-'): 1,
#           ('patient', '-'): 1,
#           ('costs', 'arising'): 1,
#           ('mean', 'whereby'): 1,
#           ('whereby', 'people'): 1,
#           ('people', 'can'): 1,
#           ('damage', 'whereby'): 1,
#           (',', 'take'): 1,
#           ('take', 'of'): 1,
#           ('public', 'due'): 1,
#           ('due', 'to'): 1,
#           (',', 'that'): 1,
#           ('prizes', 'including'): 1,
#           ('gases', 'and'): 1,
#           ('and', 'thus'): 1,
#           ('individuals', '-'): 1,
#           ('cpf', ','): 1,
#           ('which', 'might'): 1,
#           ('might', 'comes'): 1,
#           ('values', ';'): 1,
#           (';', 'where'): 1,
#           ('is', 'those'): 1,
#           ('those', 'who'): 1,
#           ('who', 'without'): 1,
#           ('without', 'families'): 1,
#           ('families', 'and'): 1,
#           ('and', 'disabilities'): 1,
#           ('disabilities', 'are'): 1,
#           ('are', 'just'): 1,
#           ('technology', '-'): 1,
#           ('development', '-'): 1,
#           ('skills', '-'): 1,
#           ('spending', ','): 1,
#           ('illness', 'because'): 1,
#           ('because', 'they'): 1,
#           ('links', '-'): 1,
#           ('sector', 'that'): 1,
#           ('up', 'and'): 1,
#           ('the', 'future-having'): 1,
#           ('more', 'simplified'): 1}),
#  'Wa': Counter({('reactors', '-'): 1,
#           ('a', 'big'): 1,
#           (',', 'gm'): 1,
#           ('years', ','): 1,
#           ('ww', '-'): 1,
#           ('r', "''"): 3,
#           ('means', 'in'): 1,
#           ('the', 'elder'): 1,
#           ('development', '('): 1,
#           ('(', 'r'): 1,
#           ('power', 'generation.ts'): 1,
#           ('stability', '&'): 1,
#           (' ', 'nparks'): 1,
#           ('countries', '-'): 1,
#           ('to', 'un'): 1,
#           ('(', 'united'): 1,
#           ('united', 'nations'): 1,
#           ('with', 'regards'): 1,
#           ('tell', '3rd'): 1,
#           ('against', 'us'): 1,
#           ('us', "'s"): 1,
#           ("'s", 'enemy'): 1,
#           ('using', 'high-tech'): 1,
#           ('the', 'cimo'): 1,
#           ('down', 'of'): 1,
#           ('care', 'for'): 1,
#           ('at', 'unc'): 1,
#           ('an', 'importance'): 1,
#           ('and', 'auto'): 1,
#           ('and', 'reasonable.ts'): 1,
#           ('(', 'un'): 1,
#           ('aged', '65+'): 1,
#           ('aged', '60+'): 1,
#           ('(', 'gm'): 1,
#           ('gm', 'food'): 1,
#           ('that', 'can'): 1,
#           ('to', 'tougher'): 1,
#           ('now', 'oecd'): 1,
#           ('spend', '-'): 1,
#           ('that', 'is'): 1,
#           ('with', 'each'): 1,
#           ('each', 'respectively'): 1,
#           ('respectively', 'increasing'): 1,
#           ('who', '-'): 1,
#           (' ', 'r'): 1,
#           ('bca', '-'): 1}),
#  'Smod': Counter({('as', 'socially'): 1,
#           ('socially', '.'): 1,
#           ('health', '-'): 1,
#           ('insufficient', 'of'): 1,
#           ('diseases', 'and'): 1,
#           ('and', 'we'): 1,
#           ('we', 'are'): 1,
#           ('are', 'incapable'): 1,
#           (' ', 'as'): 1,
#           ('as', 'aforementioned'): 1,
#           ('aforementioned', 'above'): 1,
#           ('raised', '-'): 1,
#           (',', '-'): 1,
#           ('investigation', 'of'): 1,
#           ('of', 'the'): 2,
#           ('the', 'fiasco'): 1,
#           (',', 'there'): 1,
#           ('there', 'is'): 1,
#           ('is', 'definitively'): 1,
#           ('definitively', 'a'): 1,
#           ('a', 'moral'): 1,
#           ('moral', 'obligation'): 1,
#           ('obligation', 'for'): 1,
#           ('for', 'us'): 1,
#           ('us', 'to'): 1,
#           ('to', 'provide'): 1,
#           ('provide', 'to'): 1,
#           ('to', 'our'): 1,
#           ('our', 'seniors'): 1,
#           (',', 'it'): 1,
#           ('it', 'is'): 1,
#           ('is', 'thought'): 1,
#           ('thought', 'by'): 1,
#           ('by', 'some'): 1,
#           ('some', 'theorists'): 1,
#           ('theorists', ','): 1,
#           (',', 'for'): 1,
#           ('for', 'example'): 1,
#           ('example', ','): 1,
#           (',', 'wilson'): 1,
#           ('wilson', '('): 1,
#           ('(', '2000'): 1,
#           ('2000', ')'): 1,
#           (')', ','): 1,
#           (',', 'baker'): 1,
#           ('baker', ','): 1,
#           (',', 'schuette'): 1,
#           ('schuette', 'and'): 1,
#           ('and', 'uhlmann'): 1,
#           ('uhlmann', '('): 1,
#           ('(', '1998'): 1,
#           ('1998', ')'): 1,
#           (',', 'allowing'): 1,
#           ('allowing', 'employers'): 1,
#           ('many', 'elderly'): 1,
#           ('elderly', 'people'): 1,
#           ('people', 'do'): 1,
#           ('do', 'not'): 1,
#           ('not', 'have'): 1,
#           (' ', 'taking'): 1,
#           ('taking', 'a'): 1,
#           ('a', 'look'): 1,
#           (' ', 'having'): 2,
#           ('the', 'aging'): 2,
#           ('aging', 'future'): 1,
#           ('fields', 'have'): 1,
#           ('u.s.', 'cities'): 1,
#           ('cities', 'was'): 1,
#           ('was', 'phone'): 1,
#           ('phone', 'line'): 1,
#           ('line', 'due'): 1,
#           ('due', 'to'): 1,
#           ('to', 'its'): 1,
#           ('its', 'dependence'): 1,
#           ('dependence', 'on'): 1,
#           ('on', 'a'): 1,
#           ('a', 'centralized'): 1,
#           ('centralized', 'system'): 1,
#           ('system', 'of'): 1,
#           ('of', 'above-ground'): 1,
#           (' ', 'and'): 2,
#           (' ', 'whereas'): 1,
#           ('whereas', ','): 1,
#           (' ', 'faced'): 1,
#           ('activities', 'as'): 1,
#           ('as', 'the'): 1,
#           ('aging', 'population'): 1,
#           ('population', 'increases'): 1,
#           ('increases', 'from'): 1,
#           ('from', 'time'): 1,
#           ('time', 'to'): 1,
#           ('to', 'time'): 1,
#           ('that', 'investing'): 1,
#           (' ', 'this'): 1,
#           ('this', 'process'): 1,
#           ('process', 'requires'): 1,
#           ('requires', 'finding'): 1,
#           ('finding', 'a'): 1,
#           ('a', 'suitable'): 1,
#           (',', 'government'): 1,
#           ('government', 'which'): 1,
#           ('which', 'spends'): 1,
#           ('is', 'the'): 1,
#           ('the', 'students'): 1,
#           ('students', 'are'): 1,
#           ('are', 'lack'): 1,
#           ('lack', 'of'): 1,
#           ('the', 'innovative'): 1,
#           ('innovative', 'thinking'): 1,
#           ('thinking', 'system'): 1,
#           ('after', 'comparing'): 1,
#           ('comparing', 'its'): 1,
#           ('its', 'properties'): 1,
#           (',', 'scientists'): 1,
#           ('scientists', 'hailed'): 1,
#           ('hailed', 'it'): 1,
#           ('to', '-'): 1,
#           (',', 'family'): 1,
#           ('family', 'can'): 1,
#           ('can', 'get'): 1,
#           ('however', 'comparing'): 1,
#           ('blood', 'which'): 1,
#           ('even', '-'): 1,
#           (' ', 'by'): 1,
#           ('by', 'investing'): 1,
#           ('elderly', ','): 1,
#           (',', 'this'): 1,
#           ('if', '-'): 1,
#           ('thus', ','): 1,
#           (',', 'coming'): 1,
#           ('coming', 'up'): 1,
#           ('up', 'with'): 1,
#           ('with', 'an'): 1,
#           ('an', 'effective'): 1,
#           ('effective', 'design'): 1,
#           ('design', 'for'): 1,
#           ('for', 'the'): 1,
#           ('the', 'end'): 1,
#           ('end', 'product'): 1,
#           ('having', 'emphasized'): 1,
#           ('emphasized', 'on'): 1,
#           ('on', 'the'): 1,
#           ('the', 'positive'): 1,
#           ('positive', 'aspects'): 1,
#           ('aspects', 'of'): 1,
#           ('of', 'economic'): 1,
#           ('economic', 'growth'): 1,
#           ('growth', ','): 1,
#           (',', 'unfortunately'): 1,
#           ('unfortunately', 'there'): 1,
#           ('there', 'are'): 1,
#           ('are', 'some'): 1,
#           ('some', 'drawbacks'): 1,
#           ('drawbacks', 'in'): 1,
#           ('in', 'the'): 1,
#           ('the', 'immediate'): 1,
#           ('immediate', 'short'): 1,
#           ('short', 'run'): 1,
#           ('run', '.'): 1,
#           ('technology', 'now'): 1,
#           ('now', 'a'): 1,
#           ('a', 'days'): 1,
#           ('days', 'have'): 1,
#           ('have', 'been'): 1,
#           (',', 'which'): 1,
#           ('which', 'surrounds'): 1,
#           ('surrounds', 'the'): 1,
#           ('the', 'issue'): 1,
#           ('issue', 'of'): 1,
#           ('and', 'the'): 1,
#           ('the', 'main'): 1,
#           (' ', 'comparing'): 1,
#           ('comparing', 'the'): 1,
#           ('the', 'amount'): 1,
#           ('amount', 'of'): 1,
#           ('of', 'gases'): 1,
#           ('gases', 'produced'): 1,
#           ('produced', 'by'): 1,
#           ('by', 'fossil'): 1,
#           ('fossil', 'fuels'): 1,
#           ('fuels', 'and'): 1,
#           ('and', 'by'): 1,
#           ('by', 'nuclear'): 1,
#           ('nuclear', 'power'): 1,
#           ('power', 'plant'): 1,
#           (' ', 'other'): 1,
#           ('other', 'than'): 1,
#           ('than', 'paying'): 1,
#           ('paying', 'taxes'): 1,
#           ('taxes', ','): 1,
#           (',', 'the'): 1,
#           ('the', 'working'): 1,
#           ('working', 'population'): 1,
#           ('population', 'still'): 1,
#           ('still', 'needs'): 1,
#           ('needs', 'to'): 1,
#           ('to', 'pay'): 1,
#           ('pay', 'for'): 1,
#           ('for', 'their'): 1,
#           ('their', 'personal'): 1,
#           ('personal', 'and'): 1,
#           ('and', 'family'): 1,
#           ('family', 'expenses'): 1,
#           ('expenses', '.'): 1})}

# %% [markdown]
# # Probability Calculations

# %%
error_classes = count[1].keys() # Stores the error classes
length_of_gram_vocab = {} # Keeps the count of no of tokens for each error class in i grams 
gram_vocabulary = {} # All unique tokens for each gram
error_count_keeper = {} # 

unique_grams_count = {} # Assigning the total number of unique tokens for each i gram

for i in range(1, 4):
    gram_vocabulary[i] = set() # Get the unique grams
    length_of_gram_vocab[i] = dict()
    for error in error_classes:
        gram_vocabulary[i] = gram_vocabulary[i] or set(count[i][error].keys())
        length_of_gram_vocab[i][error] = sum(count[i][error].values())
    unique_grams_count[i] = len(gram_vocabulary[i])
    
for j in range(1, 4):
    error_count_keeper[j] = {}
    for error in error_classes:
        error_count_keeper[j][error] = sum([count[j][error][k] for k in gram_vocabulary[j]]) + unique_grams_count[j]

def smoothed_probability(gram, error_class, n, smoothing_factor=0.1):
    # returns the smoothed probability
    count_of_the_gram_in_error_class = count[n][error_class][gram]
    return (count_of_the_gram_in_error_class + smoothing_factor) / error_count_keeper[n][error_class]

def load_probability():
    # initialization function
    probability = load('probability')
    if not probability:
        probability = deepcopy(count)
        for j in range(1, 4):
            for error_tags in count[j].keys():
                for gram in count[j][error_tags].keys():
                    probability[j][error_tags][gram] = smoothed_probability(gram, error_tags, j)
            save(probability, 'probability')
    print('probabilities loaded')

# %%
load_probability()
probability = load('probability')
# Out:
# probabilities loaded

# %%
print(probability[2])
# Out:
# {'Nn': Counter({('power', 'plant'): 0.0036645396536007296, ('design', 'process'): 0.0031175934366453966, ('nuclear', 'reactor'): 0.0031175934366453966, ('of', 'the'): 0.002388331814038286, ('fossil', 'fuels'): 0.002023701002734731, (',', 'the'): 0.002023701002734731, ('their', 'life'): 0.002023701002734731, (',', 'individual'): 0.0018413855970829535, ('senior', 'citizen'): 0.0018413855970829535, ('high', 'temperature'): 0.0018413855970829535, ('nuclear', 'weapon'): 0.0018413855970829535, ('nuclear', 'plant'): 0.001659070191431176, ('for', 'the'): 0.0014767547857793982, (' ', 'government'): 0.0014767547857793982, ('the', 'rights'): 0.0014767547857793982, ('energy', 'source'): 0.0014767547857793982, ('to', 'the'): 0.0012944393801276207, ('the', 'need'): 0.0012944393801276207, ('human', "'s"): 0.0012944393801276207, ('fossil', 'fuel'): 0.0012944393801276207, ('as', 'human'): 0.0011121239744758431, ('in', 'the'): 0.0011121239744758431, ('family', 'member'): 0.0011121239744758431, ('aging', 'population'): 0.0011121239744758431, ('human', 'being'): 0.0011121239744758431, ('healthcare', 'cost'): 0.0009298085688240656, ('iv', 'reactor'): 0.0009298085688240656, ('the', 'physician'): 0.0009298085688240656, ('of', 'fund'): 0.0009298085688240656, ('large', 'amount'): 0.0009298085688240656, ('daily', 'life'): 0.0009298085688240656, ('the', 'accident'): 0.0009298085688240656, ('the', 'improvement'): 0.0009298085688240656, ('lead', 'user'): 0.0009298085688240656, ('of', 'human'): 0.0009298085688240656, ('the', 'country'): 0.0009298085688240656, ('financial', 'problem'): 0.0009298085688240656, ('gasoline', 'vehicle'): 0.0009298085688240656, ('the', 'government'): 0.000747493163172288, ('of', 'a'): 0.000747493163172288, (' ', 'researches'): 0.000747493163172288, ('patient', "'s"): 0.000747493163172288, ('by', 'human'): 0.000747493163172288, ('their', 'family'): 0.000747493163172288, ('future', 'generation'): 0.000747493163172288, ('other', 'country'): 0.000747493163172288, ('in', 'term'): 0.000747493163172288, ('the', 'statistic'): 0.000747493163172288, ('of', 'reactor'): 0.000747493163172288, (' ', 'the'): 0.000747493163172288, ('research', 'staffs'): 0.000747493163172288, ('the', 'equipments'): 0.000747493163172288, ('energy', 'demand'): 0.0005651777575205106, ('with', 'regards'): 0.0005651777575205106, ('of', 'resource'): 0.0005651777575205106, ('rfid', 'implant'): 0.0005651777575205106, ('safety', 'measure'): 0.0005651777575205106, ('housing', 'estate'): 0.0005651777575205106, ('the', 'design'): 0.0005651777575205106, ('health', 'subsidy'): 0.0005651777575205106, ('of', 'lift'): 0.0005651777575205106, ('the', 'aged'): 0.0005651777575205106, ('community', 'hospital'): 0.0005651777575205106, ('younger', 'generation'): 0.0005651777575205106, ('about', 'the'): 0.0005651777575205106, ('the', '3m'): 0.0005651777575205106, ('their', 'house'): 0.0005651777575205106, (' ', 'opponent'): 0.0005651777575205106, ('nursing', 'home'): 0.0005651777575205106, ('bring', 'benefit'): 0.0005651777575205106, ('living', 'condition'): 0.0005651777575205106, ('the', 'building'): 0.0005651777575205106, ('their', 'salary'): 0.0005651777575205106, ('the', 'function'): 0.0005651777575205106, ('environmental', 'problem'): 0.0005651777575205106, ('significant', 'contribution'): 0.0005651777575205106, ('social', 'problem'): 0.0005651777575205106, ('that', 'human'): 0.0005651777575205106, ('to', 'human'): 0.0005651777575205106, ('their', 'parent'): 0.0005651777575205106, ('vulnerable', 'group'): 0.0005651777575205106, ('of', 'patient'): 0.0005651777575205106, ('plastic', 'conduit'): 0.0005651777575205106, ('energy', 'converter'): 0.0005651777575205106, ('his', 'families'): 0.0005651777575205106, ('its', 'citizen'): 0.0005651777575205106, ('of', 'accident'): 0.0005651777575205106, ('for', 'innovations'): 0.0005651777575205106, ('for', 'singaporean'): 0.0005651777575205106, ('medical', 'bill'): 0.0005651777575205106, ('in', 'hospital'): 0.0005651777575205106, ('it', 'is'):  ...

# %%
def get_prob(gram, error_class, n):
    if gram in probability[n][error_class].keys():
        return probability[n][error_class][gram]
    else:
        return smoothed_probability(gram, error_class, n)

def prob_class(grams, error_class, n, log=True):
    probs_grams = [get_prob(gram, error_class, n) for gram in grams]
    product = np.product(probs_grams)
    final_prob = product * (length_of_gram_vocab[n][error_class] / sum(length_of_gram_vocab[n].values()))
    if log:
        return np.log(final_prob)
    return final_prob

def naive_classifier(groups, n):
    temp = [(error, prob_class(groups, error, n)) for error in error_classes]
    return sorted(temp, key=lambda k: k[1], reverse=True)

# %%
sent = testing_lines[5]
print(sent)
sent_grams = lambda sent, n: [create_grams(sent, i, n) for i in range(len(sent))]
naive_classifier(sent_grams(sent, 1), 1)
# Out:
# ['if', 'the', 'fertility', 'rate', 'continues', 'to', 'drop', ',', 'there', 'will', 'be', 'not', '-', 'enough', 'young', 'people', 'to', 'replace', 'the', 'older', 'generation', '.']
# [('Um', -130.55748133735426),
#  ('WOinc', -135.29370065407343),
#  ('Rloc-', -138.3916479824075),
#  ('Wci', -139.10060319337964),
#  ('Wform', -149.9001637264522),
#  ('Srun', -150.05472153549732),
#  ('Wtone', -150.57646920497564),
#  ('Others', -154.70396730534463),
#  ('WOadv', -155.26364251327823),
#  ('Trans', -155.9737148198254),
#  ('Mec', -156.3414501118055),
#  ('Sfrag', -157.39481994691184),
#  ('Vform', -159.51688894577615),
#  ('Cit', -159.62129812550396),
#  ('Spar', -159.7527817489583),
#  ('Vt', -162.40925297347138),
#  ('Ssub', -164.81806542896786),
#  ('Vm', -165.92463888177193),
#  ('Nn', -166.59745355467874),
#  ('Prep', -170.86706237428916),
#  ('Pref', -171.95035822994535),
#  ('SVA', -173.06835631254123),
#  ('ArtOrDet', -173.0687312625282),
#  ('Smod', -174.3874199173404),
#  ('V0', -180.87962338796612),
#  ('Npos', -181.2228534992274),
#  ('Pform', -185.31109081296668),
#  ('Wa', -204.31691837286874)]
